# %% [markdown]
# # Some nGram Analysis of the FAIR-CARE Survey Text Responses

# %%
import pandas as pd

processed_survey_path = '/home/ekansa/oc-data/fair-care-survey-processed.csv' # Keep this OUT of version control, has sensitive info
ngram_freq_path = '/home/ekansa/oc-data/fair-care-ngram-freq.csv'

df = pd.read_csv(processed_survey_path, low_memory=False)
df_ngram = pd.read_csv(ngram_freq_path, low_memory=False)

print(f'FAIR+CARE survey has {len(df.index)} rows')
print(f'FAIR+CARE survey ngram extract has {len(df_ngram.index)} rows')
# Out:
# FAIR+CARE survey has 787 rows
# FAIR+CARE survey ngram extract has 396811 rows

# %%
gen_group_cols = ['column', 'ngram_len', 'ngram',]
df_ngram_gp1 = df_ngram[(gen_group_cols + ['ngram_count',])].groupby(gen_group_cols, as_index=False).sum()
df_ngram_gp1.sort_values(by=['column', 'ngram_count',], ascending=[True, False], inplace=True)
print(f'There are {len(df_ngram_gp1.index)} unique ngrams')

# Repeatly used ngrams
rep_ngram_index = df_ngram_gp1['ngram_count'] >= 10
print(f'There are {len(df_ngram_gp1[rep_ngram_index].index)} unique ngrams used 10 or more times')

df_ngram_gp1[rep_ngram_index].head(100)
# Out:
# There are 216120 unique ngrams
# There are 1691 unique ngrams used 10 or more times
#                                          column  ngram_len  \
# 248           Accessible: Additional info, Text          2
# 7531    Application of Ethical Frameworks: Text          2
# 8073    Application of Ethical Frameworks: Text          2
# 9282    Application of Ethical Frameworks: Text          3
# 8370    Application of Ethical Frameworks: Text          2
# ...                                         ...        ...
# 193834         Security: Data Security Measures          4
# 193841         Security: Data Security Measures          4
# 193854         Security: Data Security Measures          4
# 194190         Security: Data Security Measures          5
# 194200         Security: Data Security Measures          5
#
#                                      ngram  ngram_count
# 248                                data is           13
# 7531                              not sure           20
# 8073                                t know           17
# 9282                            don t know           17
# 8370                                try to           14
# ...                                    ...          ...
# 193834                on devices and files          267
# 193841      password protection on devices          267
# 193854           protection on devices and          267
# 194190  password protection on devices and          267
# 194200     protection on devices and files          267
#
# [100 rows x 4 columns]

# %%
gen_group_cols = ['Section', 'ngram_len', 'ngram',]
df_ngram_gp2 = df_ngram[(gen_group_cols + ['ngram_count',])].groupby(gen_group_cols, as_index=False).sum()
df_ngram_gp2.sort_values(by=['Section', 'ngram_count',], ascending=[True, False], inplace=True)
print(f'There are {len(df_ngram_gp1.index)} unique ngrams')
# Out:
# There are 216120 unique ngrams

# %%
# Repeatly used ngrams
# First Show results for the CARE
ngram_count_threshold = 10
section = 'CARE'
rep_ngram_index = ((df_ngram_gp2['ngram_count'] >= ngram_count_threshold) & (df_ngram_gp2['ngram_len'] >= 3) & df_ngram_gp2['Section'].isin([section]))
print(f'There are {len(df_ngram_gp2[rep_ngram_index].index)} unique ngrams used {ngram_count_threshold} or more times with {section} responses')

df_ngram_gp2[rep_ngram_index].head(50)
# Out:
# There are 48 unique ngrams used 10 or more times with CARE responses
#        Section  ngram_len                                  ngram  ngram_count
# 53323     CARE          3                             don t know           84
# 81339     CARE          4                           i don t know           71
# 61477     CARE          3              or descendant communities           30
# 50678     CARE          3                           case by case           29
# 57134     CARE          3                 indigenous peoples and           27
# 68139     CARE          3                  to indigenous peoples           25
# 50390     CARE          3                          by case basis           22
# 75779     CARE          4                     case by case basis           22
# 46443     CARE          3                              a case by           20
# 48234     CARE          3                      and or descendant           20
# 69579     CARE          3                         we are working           20
# 71390     CARE          4                         a case by case           20
# 61094     CARE          3                              on a case           18
# 86799     CARE          4                           on a case by           18
# 97742     CARE          5                   a case by case basis           18
# 112699    CARE          5                      on a case by case           18
# 62303     CARE          3                         peoples and or           17
# 70704     CARE          3                   work with indigenous           17
# 82656     CARE          4              indigenous peoples and or           17
# 63911     CARE          3                  related to indigenous           16
# 73199     CARE          4          and or descendant communities           16
# 88064     CARE          4              peoples and or descendant           16
# 108698    CARE          5   indigenous peoples and or descendant           16
# 113921    CARE          5  peoples and or descendant communities           16
# 47959     CARE          3             and descendant communities           15
# 52438     CARE          3                        data related to           15
# 52726     CARE          3                         depends on the           14
# 53330     CARE          3                            don t think           14
# 56038     CARE          3                           i googled it           14
# 60893     CARE          3                            of the data           14
# 70336     CARE          3                with indigenous peoples           14
# 81343     CARE          4                          i don t think           14
# 49350     CARE          3                             as part of           13
# 49397     CARE          3                             as well as           12
# 56195     CARE          3                              i work in           12
# 57151     CARE          3                  indigenous peoples or           12
# 52481     CARE          3                           data that is           11
# 56200     CARE          3                            i work with           11
# 60074     CARE          3                             none of my           11
# 66813     CARE          3                         the process of           11
# 69174     CARE          3                    use indigenous data           11
# 70852     CARE          3                          would like to           11
# 50423     CARE          3                  by indigenous peoples           10
# 52770     CARE          3              descendant communities in           10
# 56979     CARE          3              indigenous and descendant           10
# 60123     CARE          3                      not applicable to           10
# 60744     CARE          3                             of my work           10
# 71121     CARE          3                              yes it is           10

# %%
# Repeatly used ngrams
# First Show results for the CARE
ngram_count_threshold = 10
section = 'FAIR'
rep_ngram_index = ((df_ngram_gp2['ngram_count'] >= ngram_count_threshold) & (df_ngram_gp2['ngram_len'] >= 3) & df_ngram_gp2['Section'].isin([section]))
print(f'There are {len(df_ngram_gp2[rep_ngram_index].index)} unique ngrams used {ngram_count_threshold} or more times with {section} responses')

df_ngram_gp2[rep_ngram_index].head(50)
# Out:
# There are 1289 unique ngrams used 10 or more times with FAIR responses
#        Section  ngram_len                                  ngram  ngram_count
# 139227    FAIR          3                      devices and files          267
# 143375    FAIR          3                         on devices and          267
# 144085    FAIR          3                 password protection on          267
# 144643    FAIR          3                  protection on devices          267
# 156928    FAIR          4                   on devices and files          267
# 157655    FAIR          4         password protection on devices          267
# 158193    FAIR          4              protection on devices and          267
# 170977    FAIR          5     password protection on devices and          267
# 171469    FAIR          5        protection on devices and files          267
# 136714    FAIR          3                     and system updates          257
# 145024    FAIR          3                   regular software and          257
# 146004    FAIR          3                    software and system          257
# 158548    FAIR          4            regular software and system          257
# 159522    FAIR          4            software and system updates          257
# 171802    FAIR          5    regular software and system updates          257
# 139671    FAIR          3                    explanation of what          244
# 140479    FAIR          3                      handled data that          244
# 141316    FAIR          3               information handled data          244
# 142527    FAIR          3            missing information handled          244
# 142528    FAIR          3                         missing or why          244
# 142529    FAIR          3                     missing parts with          244
# 142845    FAIR          3                      no explanation of          244
# 144074    FAIR          3                          parts with no          244
# 146769    FAIR          3                       that was missing          244
# 148336    FAIR          3                         was missing or          244
# 148337    FAIR          3                      was missing parts          244
# 148548    FAIR          3                       what was missing          244
# 148749    FAIR          3                    with no explanation          244
# 152437    FAIR          4                  data that was missing          244
# 153148    FAIR          4                explanation of what was          244
# 153917    FAIR          4                  handled data that was          244
# 154802    FAIR          4          information handled data that          244
# 156047    FAIR          4       missing information handled data          244
# 156055    FAIR          4                  missing parts with no          244
# 156368    FAIR          4                 no explanation of what          244
# 156840    FAIR          4                    of what was missing          244
# 157645    FAIR          4              parts with no explanation          244
# 160316    FAIR          4                 that was missing parts          244
# 161949    FAIR          4                     was missing or why          244
# 161950    FAIR          4                 was missing parts with          244
# 162216    FAIR          4                    what was missing or          244
# 162442    FAIR          4                 with no explanation of          244
# 165987    FAIR          5            data that was missing parts          244
# 166661    FAIR          5        explanation of what was missing          244
# 167400    FAIR          5          handled data that was missing          244
# 168254    FAIR          5      information handled data that was          244
# 169425    FAIR          5  missing information handled data that          244
# 169433    FAIR          5      missing parts with no explanation          244
# 169731    FAIR          5             no explanation of what was          244
# 170196    FAIR          5                 of what was missing or          244
