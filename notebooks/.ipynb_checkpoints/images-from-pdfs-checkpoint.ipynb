# %%
import numpy as np
import os
import fitz
import io
from PIL import Image


# Get the root_path for this jupyter notebook repo.
repo_path = os.path.dirname(os.path.abspath(os.getcwd()))

path_pdfs = os.path.join(
    repo_path, 'files', 'pdfs'
)

file_paths = []
for dirpath, _, filenames in os.walk(path_pdfs):
    for filename in filenames:
        if filename.endswith(':Zone.Identifier'):
            # A convenience hack for Windows subsystem for linux
            continue
        if filename.startswith('.'):
            # A convenience hack for Windows subsystem for linux
            continue
        if not filename.endswith('.pdf'):
            continue
        file_path = os.path.join(dirpath, filename)
        file_paths.append(file_path)

        
num_orig = len(file_paths)
print(f'We have {num_orig} files to process')
# Out:
# We have 1421 files to process

# %%
output_format = 'png'
i = 0
for file_path in file_paths:
    i += 1
    new_path = file_path.replace('/files/pdfs/', '/files/images-from-pdfs/')
    new_dir = os.path.dirname(new_path)
    new_file = new_path.replace('.pdf', f'.{output_format}')
    if not os.path.exists(new_dir):
        os.makedirs(new_dir)
    if os.path.exists(new_file):
        continue
    print(f'[{i} of {num_orig}] working on {file_path}')
    pdf_file = fitz.open(file_path)
    pdf_image_list = []
    for page_index in range(len(pdf_file)):
        # get the page itself
        page = pdf_file[page_index]
        pdf_image_list += page.get_images(full=True)
    if not pdf_image_list:
        continue
    if len(pdf_image_list) > 1:
        print(f'[{i} of {num_orig}] {file_path} has more than {len(pdf_image_list)} images!! ')
    img_i = 0
    for img in pdf_image_list:
        if img_i > 0:
            continue
        xref = img[0]
        base_image = pdf_file.extract_image(xref)
        image_bytes = base_image["image"]
        image_ext = base_image["ext"]
        print(f'Image was a {image_ext}')
        image = Image.open(io.BytesIO(image_bytes))
        image.save(
                open(new_file, "wb"),
                format=output_format.upper(),
        )
        img_i += 1
# Out:
# [1 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-loose-paper-side-1.pdf
# Image was a png
# [2 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-245-276.pdf
# Image was a png
# [3 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-597-628-page-20.pdf
# Image was a png
# [4 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-001-031.pdf
# Image was a png
# [5 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-181-212-page-7.pdf
# Image was a png
# [6 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-150-180.pdf
# Image was a png
# [7 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-120-149.pdf
# Image was a png
# [8 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-loose-paper-side-2.pdf
# Image was a png
# [9 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-305-336.pdf
# Image was a png
# [10 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-531-563-page-18.pdf
# Image was a png
# [11 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-402-433.pdf
# Image was a png
# [12 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-277-304-page-10.pdf
# Image was a png
# [13 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-369-401.pdf
# Image was a png
# [14 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-088-119.pdf
# Image was a png
# [15 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-564-596-page-19.pdf
# Image was a png
# [16 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-213-244.pdf
# Image was a png
# [17 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-088-119-page-4.pdf
# Image was a png
# [18 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-loose-paper-side-3.pdf
# Image was a png
# [19 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-061-087-page-3.pdf
# Image was a png
# [20 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-120-149-page-5.pdf
# Image was a png
# [21 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute-loose-paper-side-7.pdf
# Image was a png
# [22 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/small-finds-1972-absolute-1-656/small-finds-1972-absolute
of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-page-39.pdf
# Image was a png
# [84 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-opposite-page-58.pdf
# Image was a png
# [85 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-page-52.pdf
# Image was a png
# [86 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-page-40.pdf
# Image was a png
# [87 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-opposite-page-50.pdf
# Image was a png
# [88 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-flints-page-1.pdf
# Image was a png
# [89 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-page-57.pdf
# Image was a png
# [90 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-page-1.pdf
# Image was a png
# [91 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-samples.pdf
# Image was a png
# [92 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-page-48.pdf
# Image was a png
# [93 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-front-cover.pdf
# Image was a png
# [94 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-page-22.pdf
# Image was a png
# [95 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-page-35.pdf
# Image was a png
# [96 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-page-56.pdf
# Image was a png
# [97 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-page-58.pdf
# Image was a png
# [98 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-opposite-page-5.pdf
# Image was a png
# [99 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-page-37.pdf
# Image was a png
# [100 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-page-53.pdf
# Image was a png
# [101 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-page-42.pdf
# Image was a png
# [102 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-page-34.pdf
# Image was a png
# [103 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-page-8.pdf
# Image was a png
# [104 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-flints-page-2.pdf
# Image was a png
# [105 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-opposite-page-51.pdf
# Image was a png
# [106 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-page-16.pdf
# Image was a png
# [107 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-inside-back-cover.pdf
# Image was a png
# [108 of 1421] working on /home/ekansa/github/open-context-jupyter/files/pdfs/trench-c-september-1972/trench-c-1972-completed-journal.pdf
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# Image was a png
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/github/open-context-jupyter/.venv/lib/python3.8/site-packages/PIL/ImageFile.py:518, in _save(im, fp, tile, bufsize)
#     517 try:
# --> 518     fh = fp.fileno()
#     519     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 28
#      26 print(f'Image was a {image_ext}')
#      27 image = Image.open(io.BytesIO(image_bytes))
# ---> 28 image.save(
#      29         open(new_file, "wb"),
#      30         format=output_format.upper(),
#      31 )
#
# File ~/github/open-context-jupyter/.venv/lib/python3.8/site-packages/PIL/Image.py:2431, in Image.save(self, fp, format, **params)
#    2428         fp = builtins.open(filename, "w+b")
#    2430 try:
# -> 2431     save_handler(self, fp, filename)
#    2432 except Exception:
#    2433     if open_fp:
#
# File ~/github/open-context-jupyter/.venv/lib/python3.8/site-packages/PIL/PngImagePlugin.py:1420, in _save(im, fp, filename, chunk, save_all)
#    1418     _write_multiple_frames(im, fp, chunk, rawmode, default_image, append_images)
#    1419 else:
# -> 1420     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1422 if info:
#    1423     for info_chunk in info.chunks:
#
# File ~/github/open-context-jupyter/.venv/lib/python3.8/site-packages/PIL/ImageFile.py:522, in _save(im, fp, tile, bufsize)
#     520     _encode_tile(im, fp, tile, bufsize, fh)
#     521 except (AttributeError, io.UnsupportedOperation) as exc:
# --> 522     _encode_tile(im, fp, tile, bufsize, None, exc)
#     523 if hasattr(fp, "flush"):
#     524     fp.flush()
#
# File ~/github/open-context-jupyter/.venv/lib/python3.8/site-packages/PIL/ImageFile.py:541, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     538 if exc:
#     539     # compress to Python file-compatible object
#     540     while True:
# --> 541         l, s, d = encoder.encode(bufsize)
#     542         fp.write(d)
#     543         if s:
#
# KeyboardInterrupt:
