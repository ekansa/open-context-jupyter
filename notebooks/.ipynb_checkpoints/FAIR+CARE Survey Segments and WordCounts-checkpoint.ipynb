# %% [markdown]
# # FAIR-CARE: Survey Segments and WordCounts

# %%
from IPython.display import display

import copy
import matplotlib.pyplot as plt

from openpyxl import Workbook

import os

import numpy as np
import pandas as pd

from slugify import slugify

# Get the root_path for this jupyter notebook repo.
repo_path = os.path.dirname(os.path.abspath(os.getcwd()))
# Use this path to save the wordcloud outputs
figs_path = os.path.join(
    repo_path, 'files', 'IMLS-FAIR-CARE-Survey', 'figs-select-word-counts',
)
rank_figs_path = os.path.join(
    repo_path, 'files', 'IMLS-FAIR-CARE-Survey', 'figs-ranks-select-options',
)
col_config_path = os.path.join(
    repo_path, 'files', 'IMLS-FAIR-CARE-Survey', 'imls-fair-care-survey-columns-config.csv',
)

processed_survey_path = '/home/ekansa/oc-data/fair-care-survey-processed.csv' # Keep this OUT of version control, has sensitive info
wide_survey_path = '/home/ekansa/oc-data/fair-care-survey-multi-select-expanded.csv' # Keep this OUT of version control, has sensitive info
semantic_clusters_path = '/home/ekansa/oc-data/fair-care-semantic-clusters-expanded.csv'
ngram_freq_path = '/home/ekansa/oc-data/fair-care-ngram-freq.csv'

df_config = pd.read_csv(col_config_path, low_memory=False)
df = pd.read_csv(processed_survey_path, low_memory=False)
df_wide = pd.read_csv(wide_survey_path, low_memory=False)
df_semantic = pd.read_csv(semantic_clusters_path, low_memory=False)
df_ngram = pd.read_csv(ngram_freq_path, low_memory=False)

print(f'FAIR+CARE survey has {len(df.index)} rows')
print(f'FAIR+CARE survey wide_survey data has {len(df_wide.index)} rows, {len(df_wide.columns)} columns')
print(f'FAIR+CARE survey semantic groupings has {len(df_semantic.index)} rows')
print(f'FAIR+CARE survey ngram extract has {len(df_ngram.index)} rows')
# Out:
# FAIR+CARE survey has 787 rows
# FAIR+CARE survey wide_survey data has 787 rows, 271 columns
# FAIR+CARE survey semantic groupings has 6128 rows
# FAIR+CARE survey ngram extract has 216860 rows

# %%
def get_original_column_metadata(column, df_config=df_config):
    """Gets the original column name from the df_config (column configuration data)"""
    config_index = (df_config['Working_Column_Name'] == column)
    if len(df_config[config_index].index) != 1:
        # We didn't find a matching column name
        return None
    row = df_config[config_index].iloc[0]
    keys = ['column', 'orig_column_index', 'Question Number', 'Section', 'Sub-Section', 'raw_column',]
    col_metadata = {k: row[k] for k in keys if k in df_config.columns.tolist()}
    return col_metadata


def get_select_option_value_from_tf_col(tf_col):
    """Gets the select option value from a TF column"""
    col_split = tf_col.split('::')
    select_option_value = col_split[1] # The second element.
    return select_option_value


def insert_line_breaks(text, max_chars):
    """Insert line breaks for long text"""
    words = text.split()  # Split the text into words
    current_line = []
    result = []
    for word in words:
        # Check if adding the next word exceeds the max_chars limit
        if len(' '.join(current_line + [word])) > max_chars:
            # Join the current line and add it to the result list
            result.append(' '.join(current_line))
            # Start a new line with the current word
            current_line = [word]
        else:
            # Add the word to the current line
            current_line.append(word)
    # Add the last line to the result list
    if current_line:
        result.append(' '.join(current_line))
    # Join all lines with a newline character
    return '\n'.join(result)


def round_up_to_base_int(x, base=50):
    rounded = x + (-x % base)
    if rounded < base:
        rounded = base
    return int(rounded)



def create_histogram_chart(
    word_counts,
    word_count_labels,
    title,
    caption,
    max_word_count,
    density=False,
    file_suffix='',
    save_dir=figs_path,
):
    """Make a histogram plot of word counts in the responses"""
    plt.style.use('seaborn-v0_8')
    num_bins = max_word_count / 5
    num_bins = int(round(num_bins, 0))
    if num_bins > 15:
        num_bins = 15
    bins = np.linspace(0, round_up_to_base_int(max_word_count), num_bins)
    if density:
        plt.hist(word_counts, bins, label=word_count_labels, density=True, )
        plt.ylabel('Normalized Density', fontsize=9)
    else:
        plt.ylabel('Count Responses', fontsize=9)
        plt.hist(word_counts, bins, label=word_count_labels, )
    plt.legend(loc='upper right')
    plt.title(title)
    xlabel = f'Response Word Counts\n{caption}'
    plt.xlabel(xlabel, fontsize=9)
    plt.tight_layout()
    plt.autoscale()
    slug_file = slugify(f'histo-{title}')
    filename = f'{slug_file}{file_suffix}.png'
    f_path = os.path.join(save_dir, filename)
    plt.savefig(f_path, bbox_inches='tight', dpi=150)
    plt.close()
    print(f'Saved figure: {filename}')


def make_filter_indices(df_wc):
    """Make lists of filter indices for charts"""
    crm_cols = [
        'Work: Work setting::CRM: Cultural Resources Consulting Firm::TF',
        'Work: Work setting::CRM: Tribally-Owned or similar Consulting Firm::TF',
        'Work: Work setting::CRM: Museum or University-based Consulting Organization::TF',
        'Work: Work setting::Construction Management Firm::TF',
        'Work: Work setting::CRM: Environmental or Engineering Consulting Firm::TF',
    ]

    # Make an index to select responses that indicate work in ANY CRM setting (lots of 'or' selections)
    any_crm_index = (df_wc[crm_cols[0]] == True)
    for crm_col in crm_cols[1:]:
        # Add an "or" option for the next CRM column
        any_crm_index |= (df_wc[crm_col] == True)
    
    
    work_group_configs = [
        ((df_wc['Work: Work setting::Academic: University or College::TF'] == True), '\nAcademic (Univ)', '-academic',),
        ((df_wc['Work: Work setting::Academic: University or College::TF'] == False), '\nNot Academic (Univ)', '-not-academic',),
        (any_crm_index, '\nCRM', '-crm',),
    ]
    
    region_configs = [
        ((df_wc['Region Focus: Work/research Region::North America (specify region)::TF'] == True), '\nN. America Focus', '-n-america',),
        ((df_wc['Region Focus: Work/research Region::North America (specify region)::TF'] == False), '\nOutside N. America Focus', '-out-n-america',),
    ]
    
    org_configs = [
        ((df_wc['Response Type: Individual or Org '] == 'Individual'), '\nResponding as Individual', '-resp-ind',),
        ((df_wc['Response Type: Individual or Org '].str.contains('Organization')), '\nResponding as Organization', '-resp-org',),
    ]
    
    filtered_plot_configs = [
        # (filter_index, title_suffix, file_suffix,),
        ((~df_wc['Response ID'].isnull()), '\nAll Reponses (Unfiltered)', '-all',),
    ] + work_group_configs + region_configs + org_configs

    return work_group_configs, region_configs, org_configs, filtered_plot_configs

# %%
# Columns used to identify responses from CRM settings
crm_cols = [
    'Work: Work setting::CRM: Cultural Resources Consulting Firm::TF',
    'Work: Work setting::CRM: Tribally-Owned or similar Consulting Firm::TF',
    'Work: Work setting::CRM: Museum or University-based Consulting Organization::TF',
    'Work: Work setting::Construction Management Firm::TF',
    'Work: Work setting::CRM: Environmental or Engineering Consulting Firm::TF',
]

wide_cols = [
    'Response ID', 
    'Demo: Age Range',	
    'Demo: Gender', 
    'Work: Work setting::Academic: University or College::TF',
    'Region Focus: Work/research Region::North America (specify region)::TF',
    'Response Type: Individual or Org ',
] + crm_cols

# Merge certain columns from the df_wide into the df_token dataset so we can
# filter by criteria from the df_wide.
sem_cols = [
    'Response ID',
    'column',
    'orig_column_index',
    'Question Number',
    'Important for Analysis',
    'Section',
    'Sub-Section',
    'response',
    'word_count',
]
df_semantic_grp = df_semantic[sem_cols].groupby(
    ['Response ID', 'column', 'orig_column_index',], 
    as_index=False
).agg(
    {
        'Question Number': 'first',
        'Important for Analysis': 'first',
        'Section': 'first',
        'Sub-Section': 'first',
        'response': 'first',
        'word_count': 'first',
    }
)

# Merge certain columns from the df_wide into the df_token dataset so we can
# filter by criteria from the df_wide.
df_wc = pd.merge(df_wide[wide_cols], df_semantic_grp, how='outer', on=['Response ID'])
df_wc_ngrams = pd.merge(df_ngram, df_wide[wide_cols], how='left', on=['Response ID'])

# %%
# Make the filter indices used for charting.
work_group_configs, region_configs, org_configs, filtered_plot_configs = make_filter_indices(df_wc)

compare_configs = [
    ('Academic, Non-Academic, CRM', '-work', work_group_configs,),
    ('N. America and Outside N. America Focus', '-regions', region_configs,),
    ('Individual and Organization Responses', '-ind-org', org_configs,),
]

# Make groups of different sections, sub-sections that we'd like to use for word counts.
use_index = df_wc['orig_column_index'] >= 38
df_sec_grp = df_wc[use_index][['Section', 'Sub-Section']].groupby(['Section', 'Sub-Section'], as_index=False).first()

# %%
chart_rows = []
for _, gr_row in df_sec_grp.iterrows():
    section = gr_row['Section']
    sub_section = gr_row['Sub-Section']
    section_index = (df_wc['Section'] == section) & (df_wc['Sub-Section'] == sub_section)
    mean_word_count = df_wc[section_index]['word_count'].mean()
    count_respondants = df_wc[section_index]['Response ID'].unique().size
    count_questions = df_wc[section_index]['column'].unique().size
    title = f'{section} -- {sub_section} Words Counts'
    caption = f'(From n = {count_respondants} individual respondants; {count_questions} freetext questions)'
    main_row = {
        'title': title,
        'caption': caption,
        'count_respondants': count_respondants,
        'count_questions': count_questions,
        'mean_word_count': mean_word_count,
    }
    for filter_index, title_suffix, file_suffix in filtered_plot_configs:
        act_filter = filter_index & section_index
        if len(df_wc[act_filter].index) < 1:
            # No need to make a wordcloud from empty data!
            continue
        segment = title_suffix.replace('\n', '')
        segment_size = df_wc[act_filter]['Response ID'].unique().size
        segment_group = f'{segment}\n(n = {segment_size} responses)'
        seg_mean_word_count = df_wc[act_filter]['word_count'].mean()
        row = copy.deepcopy(main_row)
        row['segment'] = segment_group
        row['segment_size'] = segment_size
        row['segment_mean_word_count'] = seg_mean_word_count
        chart_rows.append(row)

df_simple = pd.DataFrame(chart_rows)
df_simple.head(20)
# Out:
#                                         title  \
# 0   CARE -- Authority to Control Words Counts
# 1   CARE -- Authority to Control Words Counts
# 2   CARE -- Authority to Control Words Counts
# 3   CARE -- Authority to Control Words Counts
# 4   CARE -- Authority to Control Words Counts
# 5   CARE -- Authority to Control Words Counts
# 6   CARE -- Authority to Control Words Counts
# 7   CARE -- Authority to Control Words Counts
# 8     CARE -- Collective Benefit Words Counts
# 9     CARE -- Collective Benefit Words Counts
# 10    CARE -- Collective Benefit Words Counts
# 11    CARE -- Collective Benefit Words Counts
# 12    CARE -- Collective Benefit Words Counts
# 13    CARE -- Collective Benefit Words Counts
# 14    CARE -- Collective Benefit Words Counts
# 15    CARE -- Collective Benefit Words Counts
# 16                CARE -- Ethics Words Counts
# 17                CARE -- Ethics Words Counts
# 18                CARE -- Ethics Words Counts
# 19                CARE -- Ethics Words Counts
#
#                                               caption  count_respondants  \
# 0   (From n = 297 individual respondants; 7 freete...                297
# 1   (From n = 297 individual respondants; 7 freete...                297
# 2   (From n = 297 individual respondants; 7 freete...                297
# 3   (From n = 297 individual respondants; 7 freete...                297
# 4   (From n = 297 individual respondants; 7 freete...                297
# 5   (From n = 297 individual respondants; 7 freete...                297
# 6   (From n = 297 individual respondants; 7 freete...                297
# 7   (From n = 297 individual respondants; 7 freete...                297
# 8   (From n = 206 individual respondants; 3 freete...                206
# 9   (From n = 206 individual respondants; 3 freete...                206
# 10  (From n = 206 individual respondants; 3 freete...                206
# 11  (From n = 206 individual respondants; 3 freete...                206
# 12  (From n = 206 individual respondants; 3 freete...                206
# 13  (From n = 206 individual respondants; 3 freete...                206
# 14  (From n = 206 individual respondants; 3 freete...                206
# 15  (From n = 206 individual respondants; 3 freete...                206
# 16  (From n = 283 individual respondants; 7 freete...                283
# 17  (From n = 283 individual respondants; 7 freete...                283
# 18  (From n = 283 individual respondants; 7 freete...                283
# 19  (From n = 283 individual respondants; 7 freete...                283
#
#     count_questions  mean_word_count  \
# 0                 7        12.050936
# 1                 7        12.050936
# 2                 7        12.050936
# 3                 7        12.050936
# 4                 7        12.050936
# 5                 7        12.050936
# 6                 7        12.050936
# 7                 7        12.050936
# 8                 3        17.138614
# 9                 3        17.138614
# 10                3        17.138614
# 11                3        17.138614
# 12                3        17.138614
# 13                3        17.138614
# 14                3        17.138614
# 15                3        17.138614
# 16                7        15.352875
# 17                7        15.352875
# 18                7        15.352875
# 19                7        15.352875
#
#                                             segment  segment_size  \
# 0    All Reponses (Unfiltered)\n(n = 297 responses)           297
# 1              Academic (Univ)\n(n = 100 responses)           100
# 2          Not Academic (Univ)\n(n = 194 responses)           194
# 3                           CRM\n(n = 73 responses)            73
# 4             N. America Focus\n(n = 211 responses)           211
# 5      Outside N. America Focus\n(n = 81 responses)            81
# 6     Responding as Individual\n(n = 182 responses)           182
# 7   Responding as Organization\n(n = 106 responses)           106
# 8    All Reponses (Unfiltered)\n(n = 206 responses)           206
# 9               Academic (Univ)\n(n = 61 responses)            61
# 10         Not Academic (Univ)\n(n = 142 responses)           142
# 11                          CRM\n(n = 45 responses)            45
# 12            N. America Focus\n(n = 154 responses)           154
# 13     Outside N. America Focus\n(n = 49 responses)            49
# 14    Responding as Individual\n(n = 119 responses)           119
# 15   Responding as Organization\n(n = 83 responses)            83
# 16   All Reponses (Unfiltered)\n(n = 283 responses)           283
# 17              Academic (Univ)\n(n = 91 responses)            91
# 18         Not Academic (Univ)\n(n = 189 responses)           189
# 19                          CRM\n(n = 73 responses)            73
#
#     segment_mean_word_count
# 0                 12.050936
# 1                 11.042553
# 2                 12.642173
# 3                 10.960870
# 4                 12.686610
# 5                 10.439516
# 6                 11.733333
# 7                 13.149425
# 8                 17.138614
# 9                 15.000000
# 10                18.171429
# 11                15.413793
# 12                17.993671
# 13                14.686747
# 14                15.671053
# 15                19.720238
# 16                15.352875
# 17                15.110727
# 18                15.616299
# 19                13.235023

# %%
for comp_title, _, seg_configs in compare_configs:
    for _, gr_row in df_sec_grp.iterrows():
        section = gr_row['Section']
        sub_section = gr_row['Sub-Section']
        section_index = (df_wc['Section'] == section) & (df_wc['Sub-Section'] == sub_section)
        mean_word_count = df_wc[section_index]['word_count'].mean()
        max_word_count = df_wc[section_index]['word_count'].max()
        count_respondants = df_wc[section_index]['Response ID'].unique().size
        count_questions = df_wc[section_index]['column'].unique().size
        word_counts = []
        word_count_labels = []
        all_segments_resp_counts = 0
        for filter_index, title_suffix, _ in seg_configs:
            act_filter = filter_index & section_index
            if len(df_wc[act_filter].index) < 1:
                # No need to make a wordcloud from empty data!
                continue
            segment = title_suffix.replace('\n', '')
            segment_size = df_wc[act_filter]['Response ID'].unique().size
            segment_group = f'{segment}\n(n = {segment_size} responses)'
            word_counts.append(df_wc[act_filter]['word_count'])
            word_count_labels.append(segment_group)
            all_segments_resp_counts += segment_size
        
        title = f'{section} -- {sub_section} Words Counts\n{comp_title}'
        caption = f'(From n = {all_segments_resp_counts} individual respondants; {count_questions} freetext questions)'
        create_histogram_chart(
            word_counts=word_counts,
            word_count_labels=word_count_labels,
            title=title,
            caption=caption,
            max_word_count=max_word_count,
            density=False,
        )
        if True:
            # skip this.
            create_histogram_chart(
                word_counts=word_counts,
                word_count_labels=word_count_labels,
                title=f'{title} [Normalized]',
                caption=caption,
                max_word_count=max_word_count,
                density=True,
            )
# Out:
# Saved figure: histo-care-authority-to-control-words-counts-academic-non-academic-crm.png
# Saved figure: histo-care-authority-to-control-words-counts-academic-non-academic-crm-normalized.png
# Saved figure: histo-care-collective-benefit-words-counts-academic-non-academic-crm.png
# Saved figure: histo-care-collective-benefit-words-counts-academic-non-academic-crm-normalized.png
# Saved figure: histo-care-ethics-words-counts-academic-non-academic-crm.png
# Saved figure: histo-care-ethics-words-counts-academic-non-academic-crm-normalized.png
# Saved figure: histo-care-general-words-counts-academic-non-academic-crm.png
# Saved figure: histo-care-general-words-counts-academic-non-academic-crm-normalized.png
# Saved figure: histo-care-responsibility-words-counts-academic-non-academic-crm.png
# Saved figure: histo-care-responsibility-words-counts-academic-non-academic-crm-normalized.png
# Saved figure: histo-demographics-data-role-words-counts-academic-non-academic-crm.png
# Saved figure: histo-demographics-data-role-words-counts-academic-non-academic-crm-normalized.png
# Saved figure: histo-fair-accessible-words-counts-academic-non-academic-crm.png
# Saved figure: histo-fair-accessible-words-counts-academic-non-academic-crm-normalized.png
# Saved figure: histo-fair-findable-words-counts-academic-non-academic-crm.png
# Saved figure: histo-fair-findable-words-counts-academic-non-academic-crm-normalized.png
# Saved figure: histo-fair-interoperable-words-counts-academic-non-academic-crm.png
# Saved figure: histo-fair-interoperable-words-counts-academic-non-academic-crm-normalized.png
# Saved figure: histo-fair-reusable-words-counts-academic-non-academic-crm.png
# Saved figure: histo-fair-reusable-words-counts-academic-non-academic-crm-normalized.png
# Saved figure: histo-general-general-words-counts-academic-non-academic-crm.png
# Saved figure: histo-general-general-words-counts-academic-non-academic-crm-normalized.png
# Saved figure: histo-care-authority-to-control-words-counts-n-america-and-outside-n-america-focus.png
# Saved figure: histo-care-authority-to-control-words-counts-n-america-and-outside-n-america-focus-normalized.png
# Saved figure: histo-care-collective-benefit-words-counts-n-america-and-outside-n-america-focus.png
# Saved figure: histo-care-collective-benefit-words-counts-n-america-and-outside-n-america-focus-normalized.png
# Saved figure: histo-care-ethics-words-counts-n-america-and-outside-n-america-focus.png
# Saved figure: histo-care-ethics-words-counts-n-america-and-outside-n-america-focus-normalized.png
# Saved figure: histo-care-general-words-counts-n-america-and-outside-n-america-focus.png
# Saved figure: histo-care-general-words-counts-n-america-and-outside-n-america-focus-normalized.png
# Saved figure: histo-care-responsibility-words-counts-n-america-and-outside-n-america-focus.png
# Saved figure: histo-care-responsibility-words-counts-n-america-and-outside-n-america-focus-normalized.png
# Saved figure: histo-demographics-data-role-words-counts-n-america-and-outside-n-america-focus.png
# Saved figure: histo-demographics-data-role-words-counts-n-america-and-outside-n-america-focus-normalized.png
# Saved figure: histo-fair-accessible-words-counts-n-america-and-outside-n-america-focus.png
# Saved figure: histo-fair-accessible-words-counts-n-america-and-outside-n-america-focus-normalized.png
# Saved figure: histo-fair-findable-words-counts-n-america-and-outside-n-america-focus.png
# Saved figure: histo-fair-findable-words-counts-n-america-and-outside-n-america-focus-normalized.png
# Saved figure: histo-fair-interoperable-words-counts-n-america-and-outside-n-america-focus.png
# Saved figure: histo-fair-interoperable-words-counts-n-america-and-outside-n-america-focus-normalized.png
# Saved figure: histo-fair-reusable-words-counts-n-america-and-outside-n-america-focus.png
# Saved figure: histo-fair-reusable-words-counts-n-america-and-outside-n-america-focus-normalized.png
# Saved figure: histo-general-general-words-counts-n-america-and-outside-n-america-focus.png
# Saved figure: histo-general-general-words-counts-n-america-and-outside-n-america-focus-normalized.png
# Saved figure: histo-care-authority-to-control-words-counts-individual-and-organization-responses.png
# Saved figure: histo-care-authority-to-control-words-counts-individual-and-organization-responses-normalized.png
# Saved figure: histo-care-collective-benefit-words-counts-individual-and-organization-responses.png
# Saved figure: histo-care-collective-benefit-words-counts-individual-and-organization-responses-normalized.png
# Saved figure: histo-care-ethics-words-counts-individual-and-organization-responses.png
# Saved figure: histo-care-ethics-words-counts-individual-and-organization-responses-normalized.png
# Saved figure: histo-care-general-words-counts-individual-and-organization-responses.png
# Saved figure: histo-care-general-words-counts-individual-and-organization-responses-normalized.png
# Saved figure: histo-care-responsibility-words-counts-individual-and-organization-responses.png
# Saved figure: histo-care-responsibility-words-counts-individual-and-organization-responses-normalized.png
# Saved figure: histo-demographics-data-role-words-counts-individual-and-organization-responses.png
# Saved figure: histo-demographics-data-role-words-counts-individual-and-organization-responses-normalized.png
# Saved figure: histo-fair-accessible-words-counts-individual-and-organization-responses.png
# Saved figure: histo-fair-accessible-words-counts-individual-and-organization-responses-normalized.png
# Saved figure: histo-fair-findable-words-counts-individual-and-organization-responses.png
# Saved figure: histo-fair-findable-words-counts-individual-and-organization-responses-normalized.png
# Saved figure: histo-fair-interoperable-words-counts-individual-and-organization-responses.png
# Saved figure: histo-fair-interoperable-words-counts-individual-and-organization-responses-normalized.png
# Saved figure: histo-fair-reusable-words-counts-individual-and-organization-responses.png
# Saved figure: histo-fair-reusable-words-counts-individual-and-organization-responses-normalized.png
# Saved figure: histo-general-general-words-counts-individual-and-organization-responses.png
# Saved figure: histo-general-general-words-counts-individual-and-organization-responses-normalized.png

# %% [markdown]
# ## Make Bar Charts for the Sorted "Ideal Data Access Reuse" Question
#
# This question asked survey takers to sort the most important potential source of guidance to promote data access and reuse.

# %%
def divide_chunks(l, n):
    # looping till length l
    for i in range(0, len(l), n): 
        yield l[i:i + n]

rank_cols = [
    'Ideal Data Access Reuse: Government Regulations',
    'Ideal Data Access Reuse: Tribal Regulations, Guidelines',
    'Ideal Data Access Reuse: Research Funding Regulations, Guidelines',
    'Ideal Data Access Reuse: Institutional Rules',
    'Ideal Data Access Reuse: Financial Support for Archiving',
    'Ideal Data Access Reuse: Guidelines from Publishers, Journals',
    'Ideal Data Access Reuse: Guidelines from Repositories',
    'Ideal Data Access Reuse: Guidelines from Professional Orgs',
    'Ideal Data Access Reuse: Training for Ind and Orgs',
]

_, _, _, filtered_bar_configs = make_filter_indices(df_wc=df_wide)
rank_cols_tups = []
max_rank = 0
for rank_col in rank_cols:
    col_index = ~df_wide[rank_col].isnull()
    col_mean_rank = df_wide[col_index][rank_col].mean()
    if max_rank < col_mean_rank:
        max_rank = round_up_to_base_int(col_mean_rank, base=8)
    rank_cols_tups.append((rank_col, col_mean_rank,))

# Sort the rank columns in order of their typical ranking
sorted_rank_cols = sorted(rank_cols_tups, key=lambda x: x[1], reverse=False)

chunk_rank_cols = divide_chunks(sorted_rank_cols, n=3)


# Make an index that selects members of a segment that have made any
# ranking in the rank_col columns.
segment_any_rank_col_index = {}
for filter_index, title_suffix, file_suffix in filtered_bar_configs:
    segment = title_suffix.replace('\n', '')
    rank_col_index = df_wide[rank_cols[0]] > 0
    for rank_col in rank_cols[1:]:
        rank_col_index |= df_wide[rank_col] > 0
    filter_index &= ~df_wide['Response ID'].isnull()
    segment_any_rank_col_index[segment] = filter_index & (rank_col_index)


chunk_num = 0
for act_chunk_rank_cols in chunk_rank_cols:
    chunk_num += 1
    rank_col_labels = []
    segment_means = {}
    for rank_col, mean_rank in act_chunk_rank_cols:
        rank_col_label = rank_col.replace(': ', ':\n')
        # rank_col_label  = rank_col_label + f'\n(Mean: {round(mean_rank,2)})'
        rank_col_label  = rank_col_label
        rank_col_labels.append(rank_col_label)
        for filter_index, title_suffix, file_suffix in filtered_bar_configs:
            if file_suffix == '-all':
                # skip the all category
                continue
            act_index = (df_wide[rank_col] > 0) & filter_index
            segment = title_suffix.replace('\n', '')
            seg_size_index = segment_any_rank_col_index.get(segment)
            segment_size = len(df_wide[seg_size_index].index)
            segment_group = f'{segment}\n(n = {segment_size} responses)'
            segment_mean = 9 - df_wide[act_index][rank_col].mean()
            if not segment_means.get(segment_group):
                segment_means[segment_group] = []
            segment_means[segment_group].append(segment_mean)
    
    x = np.arange(len(rank_col_labels))  # the label locations
    width = 0.1  # the width of the bars
    multiplier = 0
    plt.style.use('tableau-colorblind10')
    fig, ax = plt.subplots(layout='constrained')
    for attribute, measurement in segment_means.items():
        offset = width * multiplier
        rects = ax.bar(x + offset, measurement, width, label=attribute)
        # ax.bar_label(rects, padding=3)
        multiplier += 1
        
    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('Mean Sort (Low to High Importance)')
    ax.set_title('Help with Data Access and Reuse, Sorted\n(Taller bars are more important)')
    ax.set_xticks(x + (width + (width * 2.75)), rank_col_labels)
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    ax.set_ylim(0, max_rank)
    plt.xticks(rotation=35, ha='right', fontsize=8)
    plt.show()
    filename = f'bar-help-with-data-access-reuse-sorting-{chunk_num}.png'
    f_path = os.path.join(rank_figs_path, filename)
    fig.savefig(f_path, bbox_inches='tight', dpi=150)
    plt.close()
    print(f'Saved figure: {filename}')
# Out:
# Saved figure: bar-help-with-data-access-reuse-sorting-1.png
# Saved figure: bar-help-with-data-access-reuse-sorting-2.png
# Saved figure: bar-help-with-data-access-reuse-sorting-3.png

# %%
from matplotlib.ticker import FuncFormatter
cat_cols = [
    'Interest in Implementing FAIR',
    'Interest in Implementing CARE',
]
cat_vals = ['Yes', 'Maybe, but I need more information', 'No',]
cat_vals_labels = ['Yes', 'Maybe, but I need\nmore information', 'No',]
for cat_col in cat_cols:
    cat_index = ~df_wide[cat_col].isnull() & (df_wide[cat_col].isin(cat_vals))
    segment_percents = {}
    max_seg_cat_percent = 0
    for filter_index, title_suffix, file_suffix in filtered_bar_configs:
        segment = title_suffix.replace('\n', '')
        seg_size_index = cat_index & filter_index
        segment_size = len(df_wide[seg_size_index].index)
        segment_group = f'{segment}\n(n = {segment_size} responses)'
        if file_suffix == '-all':
            # skip the all category
            continue
        for cat_val in cat_vals:  
            seg_cat_index = (df_wide[cat_col] == cat_val) & filter_index
            segment_cat_count = len(df_wide[seg_cat_index].index)
            percent_seg_count = round((segment_cat_count/segment_size), 2)
            print(f'segment: {segment} cat: {cat_val} count {segment_cat_count} size {segment_size} percent {percent_seg_count}')
            if max_seg_cat_percent < percent_seg_count:
                max_seg_cat_percent = percent_seg_count
            if not segment_percents.get(segment_group):
                segment_percents[segment_group] = []
            segment_percents[segment_group].append(percent_seg_count)

    x = np.arange(len(cat_vals))  # the label locations
    width = 0.1  # the width of the bars
    multiplier = 0
    plt.style.use('tableau-colorblind10')
    fig, ax = plt.subplots(layout='constrained')
    for attribute, measurement in segment_percents.items():
        offset = width * multiplier
        rects = ax.bar(x + offset, measurement, width, label=attribute)
        # ax.bar_label(rects, padding=3)
        multiplier += 1
        
    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('Percent Responses')
    ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0%}'.format(y))) 
    ax.set_title(f'{cat_col}\n(Percentage of responses in each segment)')
    ax.set_xticks(x + (width + (width * 2.75)), cat_vals_labels)
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    ax.set_ylim(0, 0.75)
    plt.xticks(rotation=35, ha='right', fontsize=8)
    plt.show()
    if 'FAIR' in cat_col:
        filename = f'bar-interest-fair.png'
    else:
        filename = f'bar-interest-care.png'
    f_path = os.path.join(rank_figs_path, filename)
    fig.savefig(f_path, bbox_inches='tight', dpi=150)
    plt.close()
    print(f'Saved figure: {filename}')
# Out:
# segment: Academic (Univ) cat: Yes count 72 size 110 percent 0.65
# segment: Academic (Univ) cat: Maybe, but I need more information count 33 size 110 percent 0.3
# segment: Academic (Univ) cat: No count 5 size 110 percent 0.05
# segment: Not Academic (Univ) cat: Yes count 100 size 241 percent 0.41
# segment: Not Academic (Univ) cat: Maybe, but I need more information count 118 size 241 percent 0.49
# segment: Not Academic (Univ) cat: No count 23 size 241 percent 0.1
# segment: CRM cat: Yes count 36 size 95 percent 0.38
# segment: CRM cat: Maybe, but I need more information count 50 size 95 percent 0.53
# segment: CRM cat: No count 9 size 95 percent 0.09
# segment: N. America Focus cat: Yes count 104 size 237 percent 0.44
# segment: N. America Focus cat: Maybe, but I need more information count 119 size 237 percent 0.5
# segment: N. America Focus cat: No count 14 size 237 percent 0.06
# segment: Outside N. America Focus cat: Yes count 63 size 109 percent 0.58
# segment: Outside N. America Focus cat: Maybe, but I need more information count 34 size 109 percent 0.31
# segment: Outside N. America Focus cat: No count 12 size 109 percent 0.11
# segment: Responding as Individual cat: Yes count 116 size 229 percent 0.51
# segment: Responding as Individual cat: Maybe, but I need more information count 95 size 229 percent 0.41
# segment: Responding as Individual cat: No count 18 size 229 percent 0.08
# segment: Responding as Organization cat: Yes count 53 size 112 percent 0.47
# segment: Responding as Organization cat: Maybe, but I need more information count 52 size 112 percent 0.46
# segment: Responding as Organization cat: No count 7 size 112 percent 0.06
# Saved figure: bar-interest-fair.png
# segment: Academic (Univ) cat: Yes count 63 size 110 percent 0.57
# segment: Academic (Univ) cat: Maybe, but I need more information count 39 size 110 percent 0.35
# segment: Academic (Univ) cat: No count 8 size 110 percent 0.07
# segment: Not Academic (Univ) cat: Yes count 95 size 242 percent 0.39
# segment: Not Academic (Univ) cat: Maybe, but I need more information count 121 size 242 percent 0.5
# segment: Not Academic (Univ) cat: No count 26 size 242 percent 0.11
# segment: CRM cat: Yes count 40 size 95 percent 0.42
# segment: CRM cat: Maybe, but I need more information count 47 size 95 percent 0.49
# segment: CRM cat: No count 8 size 95 percent 0.08
# segment: N. America Focus cat: Yes count 101 size 238 percent 0.42
# segment: N. America Focus cat: Maybe, but I need more information count 119 size 238 percent 0.5
# segment: N. America Focus cat: No count 18 size 238 percent 0.08
# segment: Outside N. America Focus cat: Yes count 52 size 109 percent 0.48
# segment: Outside N. America Focus cat: Maybe, but I need more information count 43 size 109 percent 0.39
# segment: Outside N. America Focus cat: No count 14 size 109 percent 0.13
# segment: Responding as Individual cat: Yes count 106 size 230 percent 0.46
# segment: Responding as Individual cat: Maybe, but I need more information count 102 size 230 percent 0.44
# segment: Responding as Individual cat: No count 22 size 230 percent 0.1
# segment: Responding as Organization cat: Yes count 49 size 112 percent 0.44
# segment: Responding as Organization cat: Maybe, but I need more information count 54 size 112 percent 0.48
# segment: Responding as Organization cat: No count 9 size 112 percent 0.08
# Saved figure: bar-interest-care.png

# %%
# get some nice quotesthat illustrate different groups of responses
_, _, _, filtered_quote_configs = make_filter_indices(df_wc_ngrams)

quote_configs = [
    ('CARE', 'Authority to Control', ['indigenous people',]),
    ('CARE', 'Authority to Control', ['tribal lands',]),
    ('CARE', 'Authority to Control', ['federal agency', ]),
    ('CARE', 'Authority to Control', ['don t work with indigenous',]),

    
    ('CARE', 'Collective Benefit', ['irb tribal review',]),
    # ('CARE', 'Authority to Control', ['thpo', 'shpo', ]),
    
    ('CARE', 'Ethics', ['descendant communities', ]),
    ('CARE', 'Ethics', ['human remains', ]),
    # ('CARE', 'Ethics', ['thpo', 'shpo', ]),
    
    ('CARE', 'Responsibility', ['in publications', 'local communities', ]),
    ('CARE', 'Responsibility', ['local communities', ]),
    ('CARE', 'Responsibility', ['thpo', 'shpo', ]),
    
    ('FAIR', 'Accessible', ['publicly accessible', ]),
    ('FAIR', 'Accessible', ['thpo', 'shpo', ]),
    
    ('FAIR', 'Findable', ['university library', 'institutional repository',]),
    ('FAIR', 'Findable', ['state database',]),
    
    # ('FAIR', 'Interoperable', ['thpo', 'shpo', ]),
    # ('FAIR', 'Reusable', ['thpo', 'shpo', ]),
    
    ('General', 'General', ['descendant communities', ]),
    ('General', 'General', ['indigenous communities', ]),
    # ('General', 'General', ['thpo', 'shpo', ]),
]

df_wc.sort_values(
    by=[
        'Question Number',
        'word_count',
    ],
    ascending=[
        True,
        False,
    ],
    inplace=True,
)

quote_rows = []
used_response_ids = []
for filter_index, title_suffix, file_suffix in filtered_quote_configs:
    filter_index &= ~df_wc_ngrams['Response ID'].isnull()
    segment = title_suffix.replace('\n', '')
    if segment == 'All Reponses (Unfiltered)':
        continue
    for section, sub_section, ngrams in quote_configs:
        section_index = filter_index & (df_wc_ngrams['Section'] == section) & (df_wc_ngrams['Sub-Section'] == sub_section)
        ngram_index = df_wc_ngrams['ngram'].isin(ngrams)
        search_index = section_index & (ngram_index)
        df_search_gp = df_wc_ngrams[search_index][['Response ID', 'column']].groupby(['Response ID', 'column'], as_index=False).first()
        df_search_gp.reset_index(inplace=True)
        # Use the df_search_gp as a filter (applyed using the join below) to select
        # section, sub-section, segment, and ngrams of interest.
        df_act = pd.merge(df_wc, df_search_gp, how='inner', on=['Response ID', 'column'])
        act_quotes = []
        for i, row in df_act.iterrows():
            if len(act_quotes) > 5:
                break
            response_id = row['Response ID']
            if len(df_act.index) > 5 and i < 4 and response_id in used_response_ids:
                continue
            used_response_ids.append(used_response_ids)
            column = row['column']
            col_metadata = get_original_column_metadata(column)
            quote_row = {
                'Section': section,
                'Sub-Section': sub_section,
                'segment': segment,
                'ngrams': '; '.join(ngrams),
                'column': column,
                'Question Number': row['Question Number'],
                'Response ID':response_id,
                'question': col_metadata['raw_column'],
                'response': row['response'],
            }
            act_quotes.append(quote_row)
        quote_rows += act_quotes

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
df_quotes = pd.DataFrame(quote_rows)
df_quotes.sort_values(
    by=[
        'Section',
        'Sub-Section',
        'segment',
        'ngrams',
        'Question Number',
    ],
    inplace=True,
)
display(df_quotes)
# Out:
#      Section           Sub-Section                     segment  \
# 6       CARE  Authority to Control             Academic (Univ)
# 7       CARE  Authority to Control             Academic (Univ)
# 8       CARE  Authority to Control             Academic (Univ)
# 9       CARE  Authority to Control             Academic (Univ)
# 10      CARE  Authority to Control             Academic (Univ)
# 11      CARE  Authority to Control             Academic (Univ)
# 0       CARE  Authority to Control             Academic (Univ)
# 1       CARE  Authority to Control             Academic (Univ)
# 2       CARE  Authority to Control             Academic (Univ)
# 3       CARE  Authority to Control             Academic (Univ)
# 4       CARE  Authority to Control             Academic (Univ)
# 5       CARE  Authority to Control             Academic (Univ)
# 124     CARE  Authority to Control                         CRM
# 125     CARE  Authority to Control                         CRM
# 126     CARE  Authority to Control                         CRM
# 127     CARE  Authority to Control                         CRM
# 128     CARE  Authority to Control                         CRM
# 129     CARE  Authority to Control                         CRM
# 121     CARE  Authority to Control                         CRM
# 122     CARE  Authority to Control                         CRM
# 123     CARE  Authority to Control                         CRM
# 163     CARE  Authority to Control            N. America Focus
# 164     CARE  Authority to Control            N. America Focus
# 165     CARE  Authority to Control            N. America Focus
# 166     CARE  Authority to Control            N. America Focus
# 167     CARE  Authority to Control            N. America Focus
# 168     CARE  Authority to Control            N. America Focus
# 151     CARE  Authority to Control            N. America Focus
# 152     CARE  Authority to Control            N. America Focus
# 153     CARE  Authority to Control            N. America Focus
# 154     CARE  Authority to Control            N. America Focus
# 155     CARE  Authority to Control            N. America Focus
# 156     CARE  Authority to Control            N. America Focus
# 157     CARE  Authority to Control            N. America Focus
# 158     CARE  Authority to Control            N. America Focus
# 159     CARE  Authority to Control            N. America Focus
# 160     CARE  Authority to Control            N. America Focus
# 161     CARE  Authority to Control            N. America Focus
# 162     CARE  Authority to Control            N. America Focus
# 69      CARE  Authority to Control         Not Academic (Univ)
# 70      CARE  Authority to Control         Not Academic (Univ)
# 71      CARE  Authority to Control         Not Academic (Univ)
# 72      CARE  Authority to Control         Not Academic (Univ)
# 73      CARE  Authority to Control         Not Academic (Univ)
# 74      CARE  Authority to Control         Not Academic (Univ)
# 57      CARE  Authority to Control         Not Academic (Univ)
# 58      CARE  Authority to Control         Not Academic (Univ)
# 59      CARE  Authority to Control         Not Academic (Univ)
# 60      CARE  Authority to Control         Not Academic (Univ)
# 61      CARE  Authority to Control         Not Academic (Univ)
# 62      CARE  Authority to Control         Not Academic (Univ)
# 63      CARE  Authority to Control         Not Academic (Univ)
# 64      CARE  Authority to Control         Not Academic (Univ)
# 65      CARE  Authority to Control         Not Academic (Univ)
# 66      CARE  Authority to Control         Not Academic (Univ)
# 67      CARE  Authority to Control         Not Academic (Univ)
# 68      CARE  Authority to Control         Not Academic (Univ)
# 227     CARE  Authority to Control    Outside N. America Focus
# 228     CARE  Authority to Control    Outside N. America Focus
# 229     CARE  Authority to Control    Outside N. America Focus
# 230     CARE  Authority to Control    Outside N. America Focus
# 231     CARE  Authority to Control    Outside N. America Focus
# 232     CARE  Authority to Control    Outside N. America Focus
# 226     CARE  Authority to Control    Outside N. America Focus
# 220     CARE  Authority to Control    Outside N. America Focus
# 221     CARE  Authority to Control    Outside N. America Focus
# 222     CARE  Authority to Control    Outside N. America Focus
# 223     CARE  Authority to Control    Outside N. America Focus
# 224     CARE  Authority to Control    Outside N. America Focus
# 225     CARE  Authority to Control    Outside N. America Focus
# 277     CARE  Authority to Control    Responding as Individual
# 275     CARE  Authority to Control    Responding as Individual
# 276     CARE  Authority to Control    Responding as Individual
# 268     CARE  Authority to Control    Responding as Individual
# 269     CARE  Authority to Control    Responding as Individual
# 270     CARE  Authority to Control    Responding as Individual
# 271     CARE  Authority to Control    Responding as Individual
# 272     CARE  Authority to Control    Responding as Individual
# 273     CARE  Authority to Control    Responding as Individual
# 274     CARE  Authority to Control    Responding as Individual
# 346     CARE  Authority to Control  Responding as Organization
# 347     CARE  Authority to Control  Responding as Organization
# 348     CARE  Authority to Control  Responding as Organization
# 349     CARE  Authority to Control  Responding as Organization
# 350     CARE  Authority to Control  Responding as Organization
# 340     CARE  Authority to Control  Responding as Organization
# 341     CARE  Authority to Control  Responding as Organization
# 342     CARE  Authority to Control  Responding as Organization
# 343     CARE  Authority to Control  Responding as Organization
# 344     CARE  Authority to Control  Responding as Organization
# 345     CARE  Authority to Control  Responding as Organization
# 329     CARE  Authority to Control  Responding as Organization
# 330     CARE  Authority to Control  Responding as Organization
# 331     CARE  Authority to Control  Responding as Organization
# 332     CARE  Authority to Control  Responding as Organization
# 333     CARE  Authority to Control  Responding as Organization
# 334     CARE  Authority to Control  Responding as Organization
# 335     CARE  Authority to Control  Responding as Organization
# 336     CARE  Authority to Control  Responding as Organization
# 337     CARE  Authority to Control  Responding as Organization
# 338     CARE  Authority to Control  Responding as Organization
# 339     CARE  Authority to Control  Responding as Organization
# 12      CARE    Collective Benefit             Academic (Univ)
# 13      CARE    Collective Benefit             Academic (Univ)
# 298     CARE        Responsibility    Responding as Individual
# 299     CARE        Responsibility    Responding as Individual
# 300     CARE        Responsibility    Responding as Individual
# 301     CARE        Responsibility    Responding as Individual
# 302     CARE        Responsibility    Responding as Individual
# 303     CARE        Responsibility    Responding as Individual
# 304     CARE        Responsibility    Responding as Individual
# 365     CARE        Responsibility  Responding as Organization
# 366     CARE        Responsibility  Responding as Organization
# 367     CARE        Responsibility  Responding as Organization
# 368     CARE        Responsibility  Responding as Organization
# 369     CARE        Responsibility  Responding as Organization
# 370     CARE        Responsibility  Responding as Organization
# 371     CARE        Responsibility  Responding as Organization
# 372     CARE        Responsibility  Responding as Organization
# 373     CARE        Responsibility  Responding as Organization
# 38      FAIR            Accessible             Academic (Univ)
# 39      FAIR            Accessible             Academic (Univ)
# 40      FAIR            Accessible             Academic (Univ)
# 41      FAIR            Accessible             Academic (Univ)
# 42      FAIR            Accessible             Academic (Univ)
# 143     FAIR            Accessible                         CRM
# 196     FAIR            Accessible            N. America Focus
# 197     FAIR            Accessible            N. America Focus
# 198     FAIR            Accessible            N. America Focus
# 199     FAIR            Accessible            N. America Focus
# 200     FAIR            Accessible            N. America Focus
# 98      FAIR            Accessible         Not Academic (Univ)
# 99      FAIR            Accessible         Not Academic (Univ)
# 251     FAIR            Accessible    Outside N. America Focus
# 252     FAIR            Accessible    Outside N. America Focus
# 305     FAIR            Accessible    Responding as Individual
# 306     FAIR            Accessible    Responding as Individual
# 307     FAIR            Accessible    Responding as Individual
# 308     FAIR            Accessible    Responding as Individual
# 374     FAIR            Accessible  Responding as Organization
# 375     FAIR            Accessible  Responding as Organization
# 376     FAIR            Accessible  Responding as Organization
# 43      FAIR              Findable             Academic (Univ)
# 44      FAIR              Findable             Academic (Univ)
# 45      FAIR              Findable             Academic (Univ)
# 46      FAIR              Findable             Academic (Univ)
# 47      FAIR              Findable             Academic (Univ)
# 48      FAIR              Findable             Academic (Univ)
# 145     FAIR              Findable                         CRM
# 146     FAIR              Findable                         CRM
# 147     FAIR              Findable                         CRM
# 148     FAIR              Findable                         CRM
# 149     FAIR              Findable                         CRM
# 144     FAIR              Findable                         CRM
# 207     FAIR              Findable            N. America Focus
# 208     FAIR              Findable            N. America Focus
# 209     FAIR              Findable            N. America Focus
# 210     FAIR              Findable            N. America Focus
# 211     FAIR              Findable            N. America Focus
# 201     FAIR              Findable            N. America Focus
# 202     FAIR              Findable            N. America Focus
# 203     FAIR              Findable            N. America Focus
# 204     FAIR              Findable            N. America Focus
# 205     FAIR              Findable            N. America Focus
# 206     FAIR              Findable            N. America Focus
# 106     FAIR              Findable         Not Academic (Univ)
# 107     FAIR              Findable         Not Academic (Univ)
# 108     FAIR              Findable         Not Academic (Univ)
# 109     FAIR              Findable         Not Academic (Univ)
# 110     FAIR              Findable         Not Academic (Univ)
# 100     FAIR              Findable         Not Academic (Univ)
# 101     FAIR              Findable         Not Academic (Univ)
# 102     FAIR              Findable         Not Academic (Univ)
# 103     FAIR              Findable         Not Academic (Univ)
# 104     FAIR              Findable         Not Academic (Univ)
# 183                                 human remains
# 184                                 human remains
# 185                                 human remains
# 186                                 human remains
# 76                         descendant communities
# 77                         descendant communities
# 78                         descendant communities
# 79                         descendant communities
# 80                         descendant communities
# 81                         descendant communities
# 82                                  human remains
# 83                                  human remains
# 84                                  human remains
# 85                                  human remains
# 86                                  human remains
# 87                                  human remains
# 233                        descendant communities
# 234                        descendant communities
# 235                        descendant communities
# 236                        descendant communities
# 237                        descendant communities
# 238                        descendant communities
# 239                                 human remains
# 282                        descendant communities
# 283                        descendant communities
# 284                        descendant communities
# 285                        descendant communities
# 286                        descendant communities
# 287                        descendant communities
# 288                                 human remains
# 289                                 human remains
# 290                                 human remains
# 291                                 human remains
# 292                                 human remains
# 293                                 human remains
# 353                        descendant communities
# 354                        descendant communities
# 355                        descendant communities
# 356                        descendant communities
# 357                        descendant communities
# 358                        descendant communities
# 359                                 human remains
# 360                                 human remains
# 361                                 human remains
# 362                                 human remains
# 363                                 human remains
# 364                                 human remains
# 28             in publications; local communities
# 29             in publications; local communities
# 30             in publications; local communities
# 31             in publications; local communities
# 32             in publications; local communities
# 33             in publications; local communities
# 34                              local communities
# 35                              local communities
# 36                              local communities
# 37                              local communities
# 141            in publications; local communities
# 142            in publications; local communities
# 187            in publications; local communities
# 188            in publications; local communities
# 189            in publications; local communities
# 190            in publications; local communities
# 191            in publications; local communities
# 192            in publications; local communities
# 193                             local communities
# 194                             local communities
# 195                             local communities
# 88             in publications; local communities
# 89             in publications; local communities
# 90             in publications; local communities
# 91             in publications; local communities
# 92             in publications; local communities
# 93             in publications; local communities
# 94                              local communities
# 95                              local communities
# 96                              local communities
# 97                              local communities
# 240            in publications; local communities
# 241            in publications; local communities
# 242            in publications; local communities
# 243            in publications; local communities
# 244            in publications; local communities
# 245            in publications; local communities
# 246                             local communities
# 247                             local communities
# 248                             local communities
# 249                             local communities
# 250                             local communities
# 294            in publications; local communities
# 295            in publications; local communities
# 296            in publications; local communities
# 297            in publications; local communities
# 298            in publications; local communities
# 299            in publications; local communities
# 300                             local communities
# 301                             local communities
# 302                             local communities
# 303                             local communities
# 304                             local communities
# 365            in publications; local communities
# 366            in publications; local communities
# 367            in publications; local communities
# 368            in publications; local communities
# 369            in publications; local communities
# 370            in publications; local communities
# 371                             local communities
# 372                             local communities
# 373                             local communities
# 38                            publicly accessible
# 39                            publicly accessible
# 40                            publicly accessible
# 41                            publicly accessible
# 42                            publicly accessible
# 143                           publicly accessible
# 196                           publicly accessible
# 197                           publicly accessible
# 198                           publicly accessible
# 199                           publicly accessible
# 200                           publicly accessible
# 98                            publicly accessible
# 99                            publicly accessible
# 251                           publicly accessible
# 252                           publicly accessible
# 305                           publicly accessible
# 306                           publicly accessible
# 307                           publicly accessible
# 308                           publicly accessible
# 374                           publicly accessible
# 375                           publicly accessible
# 376                           publicly accessible
# 43   university library; institutional repository
# 44   university library; institutional repository
# 45   university library; institutional repository
# 46   university library; institutional repository
# 47   university library; institutional repository
# 48   university library; institutional repository
# 145                                state database
# 146                                state database
# 147                                state database
# 148                                state database
# 149                                state database
# 144  university library; institutional repository
# 207                                state database
# 208                                state database
# 209                                state database
# 210                                state database
# 211                                state database
# 201  university library; institutional repository
# 202  university library; institutional repository
# 203  university library; institutional repository
# 204  university library; institutional repository
# 205  university library; institutional repository
# 206  university library; institutional repository
# 106                                state database
# 107                                state database
# 108                                state database
# 109                                state database
# 110                                state database
# 100  university library; institutional repository
# 101  university library; institutional repository
# 102  university library; institutional repository
# 103  university library; institutional repository
# 104  university library; institutional repository
# 105  university library; institutional repository
# 253  university library; institutional repository
# 254  university library; institutional repository
# 255  university library; institutional repository
# 256  university library; institutional repository
# 257  university library; institutional repository
# 258  university library; institutional repository
# 315                                state database
# 316                                state database
# 317                                state database
# 318                                state database
# 309  university library; institutional repository
# 310  university library; institutional repository
# 311  university library; institutional repository
# 312  university library; institutional repository
# 313  university library; institutional repository
# 314  university library; institutional repository
# 382                                state database
# 377  university library; institutional repository
# 378  university library; institutional repository
# 379  university library; institutional repository
# 380  university library; institutional repository
# 381  university library; institutional repository
# 49                         descendant communities
# 50                         descendant communities
# 51                         descendant communities
# 52                         descendant communities
# 53                         descendant communities
# 54                         descendant communities
# 55                         indigenous communities
# 56                         indigenous communities
# 150                        indigenous communities
# 212                        descendant communities
# 213                        descendant communities
# 214                        descendant communities
# 215                        descendant communities
# 216                        descendant communities
# 217                        descendant communities
# 218                        indigenous communities
# 219                        indigenous communities
# 111                        descendant communities
# 112                        descendant communities
# 113                        descendant communities
# 114                        descendant communities
# 115                        descendant communities
# 116                        indigenous communities
# 117                        indigenous communities
# 118                        indigenous communities
# 119                        indigenous communities
# 120                        indigenous communities
# 259                        descendant communities
# 260                        descendant communities
# 261                        descendant communities
# 262                        descendant communities
# 263                        indigenous communities
# 264                        indigenous communities
# 265                        indigenous communities
# 266                        indigenous communities
# 267                        indigenous communities
# 319                        descendant communities
# 320                        descendant communities
# 321                        descendant communities
# 322                        descendant communities
# 323                        descendant communities
# 324                        descendant communities
# 325                        indigenous communities
# 326                        indigenous communities
# 327                        indigenous communities
# 328                        indigenous communities
# 383                        descendant communities
# 384                        descendant communities
# 385                        indigenous communities
# 386                        indigenous communities
# 387                        indigenous communities
#
#                                                                              column  \
# 6     Control Policies: Polices for Indigenous Use, Refusal, Reclaim Data? No, Text
# 7     Control Policies: Polices for Indigenous Use, Refusal, Reclaim Data? No, Text
# 8                                           How Communities Identified: Other, Text
# 9                                           Practices Prior to Sharing: Other, Text
# 10                        Informed Consent: Required Informed Consent Yes, No, Text
# 11             Collaboration Processes: Collaboration Processes Exist Yes, No, Text
# 0     Control Policies: Polices for Indigenous Use, Refusal, Reclaim Data? No, Text
# 1     Control Policies: Polices for Indigenous Use, Refusal, Reclaim Data? No, Text
# 2                                           How Communities Identified: Other, Text
# 3                                           Practices Prior to Sharing: Other, Text
# 4                                           Practices Prior to Sharing: Other, Text
# 5                         Informed Consent: Required Informed Consent Yes, No, Text
# 124  Control Policies: Polices for Indigenous Use, Refusal, Reclaim Data? Yes, Text
# 125                                         How Communities Identified: Other, Text
# 126                                         Practices Prior to Sharing: Other, Text
# 127                                         Practices Prior to Sharing: Other, Text
# 128                       Informed Consent: Required Informed Consent Yes, No, Text
# 129            Collaboration Processes: Collaboration Processes Exist Yes, No, Text
# ...
# 321                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      The question of ethical access, use, and preservation of data is an important issue for all research efforts, not only as pertains to indigenous and descendant communities. These issues need to be addressed at a national level to ensure that data from decades of work is preserved and accessible for generations to come. The transformation of data and digital revolution have changed the fundamentals of data archiving and we risk losing generations of research productivity and data due to neglect on the part of institutions and individuals.
# 322                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Mostly that I know how I want and should operate concerning sharing information and data with Indigenous Peoples and descendant communities but it is often impacted by the fact that I cannot afford to lose my job. I want to be open and communicative because I don't think this information or these artifacts are ours to hoard but it's hard to get other people (sometimes older people in the field specifically) to change their ways.
# 323                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       I would like to clarify that my work does not take into consideration Indigenous Peoples' or Descendant Communities' data rights not because I do not think they're important, but because there are no such communities for me to engage with
# 324                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       The vocabulary of Indigenous and descendant communities does not apply well to my work in Türkiye. Here local communities are involved in projects but they are rarely considered indigenous or descendants and the turkish government regulates archaeological data collection and management
# 325                                                                                                                                                                                                                                                                                                                                                                   During this survey I have realized how my aspirations to be engage and be involved with indigenous communities in my research have not aligned with my practices. I am currently a PhD student and would say I have less control over reaching out to the indigenous communities that are assoicated with the materials I work with (lab samples for radiocarbon and stable isotope analysis). I feel like I could be doing more to hold my supervisors and the head project organizers accountable or ask them more detailed questions about how the larger project is engaging with indigenous communities. I think there is a further disconnect between laboratory researchers since we may never go to the excavation sites our materials come from and have less opportunity for in-person communication with local groups.
# 326                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     I appreciate the difficulty in designing a survey that can be used across a very wide range of research settings and Indigenous communities. Many of my answers have been highly contingent on which communities and contexts in which we work.
# 327                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     There are parts of the world where there are no Indigenous communities so interaction with them is rare or only at second-hand. This makes some of the questions irrelevant and you provide no options to address this (it is firmly grounded in North American practice and experience which is different from elsewhere). I had difficulty with some being based in the UK, and I am sure responders in e.g. other European, Asian and African countries might find the same.
# 328                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   CARE isn't just about indigenous communities. For example, in Anatolian archaeology, the term indigenous is very rarely used, if at all. There are very few and very specific instances indigenous may be an applicable term, for example when talking about displaced communities of Greek and Arrmenian descent post WWI. CARE principles take into consideration all stakeholders, including but not limited to ethnic and/or religious minorities. The way the questions were phrased therefore felt limiting.
# 383                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           It is fascinating that the questions in the second half are completely focused on 'indigenous' and 'descendant' communities within an American context. When answering, I gave not a thought to how practices would be applied to the OTHER place where our operations are conducted - the Mediterranean.
# 384                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                This was an interesting survey, I work for a Tribal government, so a lot of this type of thing is built in. I appreciate that folks are looking at these issues. I feel strongly that data from indigenous or descendant communities should not be used without clear consent from those communities and that institutions should solicit and follow government (i.e., tribal) level policies in general (so that Tribes are not overwhelmed with research requests).
# 385                                                                                                                                                                                                                        The greatest impediment to promotion of FAIR and CARE values in our industry is the situation of consultants in the development approvals process; established bureaucracy, proponent rights frameworks, and liability concerns make it difficult for consultant archaeologists to always follow best practices because there is no legal basis (or financial basis!) to force the matter. Change comes slowly, but it comes. The Indigenous communities themselves are the most influential agents of change. Likewise, technological developments, particularly in data storage, transmission, and accessibility platforms, are making it far simpler, faster, and cheaper to make information available in a responsible way. Also, heritage professionals are far more savvy these days about data structure, security, and management compared to a decade ago. It's inevitable that there will be more data available; the question is: how well will we deal with it?
# 386                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   We believe that it is important to have overall guidelines, but each institution needs to reach out to impacted Indigenous communities and create open dialogs. The failure to do so in the past is why repatriation was such a contentious issue.
# 387                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Guidelines for contacting  & working with experts from indigenous communities would be helpful.

# %%
df_quotes.to_excel('/home/ekansa/oc-data/fair-care-quotes.xlsx')

# %%
df_wc_sem = pd.merge(df_wide[wide_cols], df_semantic, how='outer', on=['Response ID'])

# Make the filter indices used for semantic group display
_, _, _, filtered_sem_configs = make_filter_indices(df_wc_sem)

semantic_group_col = 'semantic_cluster_id'
sem_groups_index = ~df_wc_sem[semantic_group_col].isnull()
sem_group_cols = ['Section', 'Sub-Section', 'column', 'Question Number', semantic_group_col,]

df_sem_grps = df_wc_sem[sem_groups_index][sem_group_cols].groupby(sem_group_cols, as_index=False).first()

sem_id_quotes = []
skips = []
for _, row in df_sem_grps.iterrows():
    section = row['Section']
    sub_section = row['Sub-Section']
    column = row['column']
    question_num = row['Question Number']
    semantic_id = row[semantic_group_col]
    sem_id_index = (
        (df_wc_sem['Section'] == section)
        & (df_wc_sem['Sub-Section'] == sub_section)
        & (df_wc_sem['column'] == column)
        & (df_wc_sem['Question Number'] == question_num)
        & (df_wc_sem[semantic_group_col] == semantic_id)
    )
    col_metadata = get_original_column_metadata(column)
    all_sem_id_count = df_wc_sem[sem_id_index]['Response ID'].nunique()
    sem_id_row = {
        'Section': section,
        'Sub-Section': sub_section,
        'semantic_id_count::all': all_sem_id_count,
    }

    segment_count_tups = []
    for filter_index, title_suffix, file_suffix in filtered_sem_configs:
        filter_index &= ~df_wc_sem['Response ID'].isnull()
        segment = title_suffix.replace('\n', '')
        if segment == 'All Reponses (Unfiltered)':
            continue
        act_index = sem_id_index & filter_index
        segment_count = df_wc_sem[act_index]['Response ID'].nunique()
        sem_id_row[f'semantic_id_percent::{segment}'] = round((segment_count / all_sem_id_count), 4) * 100
        segment_count_tups.append((segment, segment_count,))

    sorted_segment_count_tups = sorted(segment_count_tups, key=lambda x: x[1], reverse=True)
    sem_id_row['main_segment'] = sorted_segment_count_tups[0][0]

    sem_id_row['column'] = column
    sem_id_row['Question Number'] = question_num
    sem_id_row['question'] = col_metadata['raw_column']
    sem_id_row[semantic_group_col] = semantic_id
    
    for filter_index, title_suffix, file_suffix in filtered_plot_configs:
        filter_index &= ~df_wc_sem['Response ID'].isnull()
        segment = title_suffix.replace('\n', '')
        if segment == 'All Reponses (Unfiltered)':
            continue
        act_index = sem_id_index & filter_index
        act_quotes = []
        for i, row in df_wc_sem[act_index].iterrows():
            if len(act_quotes) > 3:
                break
            response_id = row['Response ID']
            skip_key = (response_id, question_num, semantic_id)
            if skip_key in skips:
                continue
            skips.append(skip_key)
            quote_row = copy.deepcopy(sem_id_row)
            quote_row['segment'] = segment
            quote_row['Response ID'] = response_id
            quote_row['response'] = row['response']
            act_quotes.append(quote_row)
        sem_id_quotes += act_quotes



pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
df_sem_quotes = pd.DataFrame(sem_id_quotes)
df_sem_quotes.sort_values(
    by=[
        'Section',
        'Sub-Section',
        'Question Number',
        semantic_group_col,
    ],
    inplace=True,
)
display(df_sem_quotes[['Sub-Section', 'column', 'segment', semantic_group_col, 'Response ID', 'question', 'response']])
# Out:
#                Sub-Section  \
# 70    Authority to Control
# 71    Authority to Control
# 72    Authority to Control
# 73    Authority to Control
# 74    Authority to Control
# 75    Authority to Control
# 84    Authority to Control
# 85    Authority to Control
# 86    Authority to Control
# 87    Authority to Control
# 88    Authority to Control
# 89    Authority to Control
# 90    Authority to Control
# 91    Authority to Control
# 76    Authority to Control
# 77    Authority to Control
# 78    Authority to Control
# 79    Authority to Control
# 92    Authority to Control
# 93    Authority to Control
# 94    Authority to Control
# 95    Authority to Control
# 80    Authority to Control
# 81    Authority to Control
# 82    Authority to Control
# 83    Authority to Control
# 96    Authority to Control
# 97    Authority to Control
# 98    Authority to Control
# 99    Authority to Control
# 100   Authority to Control
# 101   Authority to Control
# 102   Authority to Control
# 103   Authority to Control
# 104   Authority to Control
# 105   Authority to Control
# 106   Authority to Control
# 107   Authority to Control
# 163   Authority to Control
# 164   Authority to Control
# 165   Authority to Control
# 166   Authority to Control
# 167   Authority to Control
# 168   Authority to Control
# 169   Authority to Control
# 170   Authority to Control
# 171   Authority to Control
# 172   Authority to Control
# 173   Authority to Control
# 174   Authority to Control
# 175   Authority to Control
# 176   Authority to Control
# 177   Authority to Control
# 178   Authority to Control
# 179   Authority to Control
# 180   Authority to Control
# 181   Authority to Control
# 182   Authority to Control
# 183   Authority to Control
# 108   Authority to Control
# 109   Authority to Control
# 110   Authority to Control
# 111   Authority to Control
# 112   Authority to Control
# 113   Authority to Control
# 114   Authority to Control
# 115   Authority to Control
# 116   Authority to Control
# 117   Authority to Control
# 118   Authority to Control
# 119   Authority to Control
# 120   Authority to Control
# 121   Authority to Control
# 122   Authority to Control
# 123   Authority to Control
# 124   Authority to Control
# 125   Authority to Control
# 126   Authority to Control
# 127   Authority to Control
# 128   Authority to Control
# 129   Authority to Control
# 130   Authority to Control
# 131   Authority to Control
# 132   Authority to Control
# 133   Authority to Control
# 134   Authority to Control
# 135   Authority to Control
# 136   Authority to Control
# 137   Authority to Control
# 138   Authority to Control
# 139   Authority to Control
# 140   Authority to Control
# 141   Authority to Control
# 142   Authority to Control
# 143   Authority to Control
# 144   Authority to Control
# 145   Authority to Control
# 146   Authority to Control
# 147   Authority to Control
# 148   Authority to Control
# 149   Authority to Control
# 150   Authority to Control
# 151   Authority to Control
# 152   Authority to Control
# 153   Authority to Control
# 154   Authority to Control
# 155   Authority to Control
# 156   Authority to Control
# 157   Authority to Control
# 158   Authority to Control
# 159   Authority to Control
# 160   Authority to Control
# 161   Authority to Control
# 162   Authority to Control
# 0     Authority to Control
# 1     Authority to Control
# 2     Authority to Control
# 3     Authority to Control
# 4     Authority to Control
# 5     Authority to Control
# 6     Authority to Control
# 7     Authority to Control
# 1247              Findable
# 1248              Findable
# 1249              Findable
# 1250              Findable
# 1251              Findable
# 1252              Findable
# 1253              Findable
# 1254              Findable
# 1255              Findable
# 1256              Findable
# 1257              Findable
# 1258              Findable
# 1259              Findable
# 1260              Findable
# 1261              Findable
# 1262              Findable
# 1263              Findable
# 1264              Findable
# 1265              Findable
# 1266              Findable
# 1273              Findable
# 1274              Findable
# 1275              Findable
# 1276              Findable
# 1277              Findable
# 1278              Findable
# 1279              Findable
# 1280              Findable
# 1281              Findable
# 1282              Findable
# 1283              Findable
# 1284              Findable
# 1289              Findable
# 1290              Findable
# 1291              Findable
# 1292              Findable
# 1293              Findable
# 1294              Findable
# 1295              Findable
# 1296              Findable
# 1297              Findable
# 1298              Findable
# 1299              Findable
# 1267              Findable
# 1268              Findable
# 1269              Findable
# 1270              Findable
# 1271              Findable
# 1272              Findable
# 1285              Findable
# 1286              Findable
# 1287              Findable
# 1288              Findable
# 1300              Findable
# 1301              Findable
# 1302              Findable
# 1303              Findable
# 1304              Findable
# 1305              Findable
# 1306              Findable
# 1307              Findable
# 1308              Findable
# 1309              Findable
# 1310              Findable
# 1311              Findable
# 1312              Findable
# 1313              Findable
# 1314              Findable
# 1315              Findable
# 1316              Findable
# 1317              Findable
# 1318              Findable
# 1319              Findable
# 1320              Findable
# 1321              Findable
# 1322              Findable
# 1323              Findable
# 1324              Findable
# 1325              Findable
# 1326              Findable
# 1327              Findable
# 1328              Findable
# 1329              Findable
# 1330              Findable
# 1331              Findable
# 1332              Findable
# 1333              Findable
# 1334              Findable
# 1335              Findable
# 1336              Findable
# 1337              Findable
# 1338              Findable
# 1339              Findable
# 1340              Findable
# 1341              Findable
# 1342              Findable
# 1343              Findable
# 1344              Findable
# 1345              Findable
# 1346              Findable
# 1347              Findable
# 1348              Findable
# 1349              Findable
# 1350              Findable
# 1351              Findable
# 1352              Findable
# 1353              Findable
# 1354              Findable
# 1355              Findable
# 1356              Findable
# 1357              Findable
# 1358              Findable
# 1359              Findable
# 1360              Findable
# 1361              Findable
# 1362              Findable
# 1363              Findable
# 1364              Findable
# 1213              Findable
# 1214              Findable
# 1215              Findable
# 1216              Findable
# 1217              Findable
# 1218              Findable
# 1219              Findable
# 1220              Findable
# 1221              Findable
# 1222              Findable
# 1223              Findable
# 1401         Interoperable
# 1402         Interoperable
# 1403         Interoperable
# 1404         Interoperable
# 1405         Interoperable
# 1406         Interoperable
# 1407         Interoperable
# 1408         Interoperable
# 1409         Interoperable
# 1410         Interoperable
# 1365         Interoperable
# 1366         Interoperable
# 1367         Interoperable
# 1368         Interoperable
# 1369         Interoperable
# 1370         Interoperable
# 1371         Interoperable
# 1372         Interoperable
# 1373         Interoperable
# 1374         Interoperable
# 1375         Interoperable
# 1376         Interoperable
# 1377         Interoperable
# 1378         Interoperable
# 1379         Interoperable
# 1380         Interoperable
# 1381         Interoperable
# 1382         Interoperable
# 1383         Interoperable
# 1384         Interoperable
# 1385         Interoperable
# 1386         Interoperable
# 1387         Interoperable
# 1388         Interoperable
# 1389         Interoperable
# 1390         Interoperable
# 1391         Interoperable
# 1392         Interoperable
# 1393         Interoperable
# 1394         Interoperable
# 1395         Interoperable
# 1396         Interoperable
# 1397         Interoperable
# 1398         Interoperable
# 1399         Interoperable
# 1400         Interoperable
# 1411              Reusable
# 1412              Reusable
# 1413              Reusable
# 1414              Reusable
# 1415              Reusable
# 1416              Reusable
# 1417              Reusable
# 1418              Reusable
# 1419              Reusable
# 1424              Reusable
# 1425              Reusable
# 1426              Reusable
# 1427              Reusable
# 1428              Reusable
# 1429              Reusable
# 1430              Reusable
# 1431              Reusable
# 1432              Reusable
# 1433              Reusable
# 1434              Reusable
# 1435              Reusable
# 1436              Reusable
# 1420              Reusable
# 1421              Reusable
# 1422              Reusable
# 1423              Reusable
# 1437              Reusable
# 1438              Reusable
# 1439              Reusable
# 1440              Reusable
# 1441              Reusable
# 1442              Reusable
# 1443              Reusable
# 1444              Reusable
# 1445              Reusable
# 1446              Reusable
# 1447              Reusable
# 1448              Reusable
# 1449              Reusable
# 1450              Reusable
# 1451              Reusable
# 1452              Reusable
# 1453              Reusable
# 1454              Reusable
# 1455              Reusable
# 1456              Reusable
# 1457              Reusable
# 1458              Reusable
# 1459              Reusable
# 1460              Reusable
# 1461              Reusable
# 1462              Reusable
# 1463              Reusable
# 1468              Reusable
# 1469              Reusable
# 1470              Reusable
# 1471              Reusable
# 1472              Reusable
# 1473              Reusable
# 1474              Reusable
# 1475              Reusable
# 1476              Reusable
# 1477              Reusable
# 1478              Reusable
# 1479              Reusable
# 1480              Reusable
# 1481              Reusable
# 1482              Reusable
# 1483              Reusable
# 1484              Reusable
# 1485              Reusable
# 1486              Reusable
# 1487              Reusable
# 1464              Reusable
# 1465              Reusable
# 1466              Reusable
# 1467              Reusable
# 1509               General
# 1510               General
# 1511               General
# 1512               General
# 1513               General
# 1514               General
# 1515               General
# 1516               General
# 1517               General
# 1518               General
# 1519               General
# 1520               General
# 1521               General
# 1522               General
# 1523               General
# 1524               General
# 1525               General
# 1526               General
# 1527               General
# 1528               General
# 1529               General
# 1530               General
# 1531               General
# 1532               General
# 1533               General
# 1534               General
# 1535               General
# 1536               General
# 1537               General
# 1538               General
# 1539               General
# 1540               General
# 1541               General
# 1542               General
# 1543               General
# 1544               General
# 1545               General
# 1546               General
# 1547               General
# 1548               General
# 1549               General
# 1550               General
# 1551               General
# 1552               General
# 1553               General
# 1554               General
# 1555               General
# 1556               General
# 1557               General
# 1558               General
# 1559               General
# 1560               General
# 1561               General
# 1562               General
# 1563               General
# 1564               General
# 1565               General
# 1566               General
# 1567               General
# 1568               General
# 1569               General
# 1570               General
# 1571               General
# 1572               General
# 1573               General
# 1574               General
# 1575               General
# 1576               General
# 1488               General
# 1489               General
# 1490               General
# 1491               General
# 1492               General
# 1493               General
# 1494               General
# 1495               General
# 1496               General
# 1497               General
# 1498               General
# 1499               General
# 1500               General
# 1501               General
# 1502               General
# 1503               General
# 1504               General
# 1505               General
# 1506               General
# 1507               General
# 1508               General
# 1577               General
# 1578               General
# 1579               General
# 1580               General
# 1581               General
# 1582               General
# 1583               General
# 1584               General
#
#                                                                               column  \
# 70     Control Policies: Polices for Indigenous Use, Refusal, Reclaim Data? No, Text
# 71     Control Policies: Polices for Indigenous Use, Refusal, Reclaim Data? No, Text
# 72     Control Policies: Polices for Indigenous Use, Refusal, Reclaim Data? No, Text
# ...
# 1580                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     The section about consultation left room for ambiguity that had me on the fence about answers. For example, I said "no" we don't consult on our data management plan, but that's because we don't have such a plan, not because we wouldn't consult. I wish there had been an N/A option there. I think most of my "no" answers should have been "N/A". Others with the same struggle might leave it blank. As someone who has collected survey data before, I predict that section will be one of the problem children to interpret, which is a bummer, but to be expected in any big survey.
# 1581                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                My ethical treatment towards Indigenous “data” is to return it to tribes, not to store or share it.
# 1582                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              This was an interesting survey, I work for a Tribal government, so a lot of this type of thing is built in. I appreciate that folks are looking at these issues. I feel strongly that data from indigenous or descendant communities should not be used without clear consent from those communities and that institutions should solicit and follow government (i.e., tribal) level policies in general (so that Tribes are not overwhelmed with research requests).
# 1583                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 I don't work at all with indigenous data. I did not see any other option in the survey to indicate this. \nQ45: I was already before interested in implementing FAIR practices. I picked "yes" in lack of a more suitable answer.
# 1584  I did have a reaction to the statement "Indigenous Peoples’ rights and well-being should be the primary concern at all stages of the data life cycle and across the data ecosystem." I agree with this statement and I understand this statement is in alignment with the intention of that section of the survey. I feel strongly that the rights and well-being of the scientific/archaeological community should be held in kind. The tribal and scientific perspectives are not necessarily in opposition to each other. Each provides a unique perspective on the past. We have found during engagements that the tribal members learn much from us as we learn much from them. My experience is that they respect the scientific information and we have policies that as archaeologists we respect their perspectives as well. I have a concern that arose in the 1990s that many archaeologists began to abdicate the rights granted to them in federal and state laws and regulations in the desire to avoid conflict and appease tribal communities rather than ask a simple question as granted by the regulations and freely accept "yes" or "no" as the tribe's response. I have a concern about the current conversation within the archaeological community that "demonizes" (maybe too harsh a word) the scientific/archaeological methods. This conversation, in my opinion is misdirected and perpetuates the apparent conflict between archaeologists and tribes on who owns the past and has the right to tell the story. My opinion is that each perspective, line of inquiry has something to offer that enriches the story of the past. My opinion that in some ethnographic studies heritage sites have been misclassified in deference to tribal opinion or support of tribal opinion. I am not sure which it is because the classifications are not attributed to the tribal members interviewed or non-tribal archaeologists involved who prepared the report. Sites without the empirical attributes of habitation were classified as ancestral habitations. This of course is my archaeological opinion based on a few decades of experience. During tribal engagements, tribal members unaccustomed to stone tools have become acquainted with how certain stone tools may have been used base on archaeological studies and experiments. They have learned what we know about indigenous pottery and what we know from provenance studies of various traditions and types. Members have also provided their insights to us. I have been witness to a mutually respectful exchange of knowledge. The archaeological knowledge gained enriched their connection to their ancestors and the traces of their ancestors on the landscape. I'm just going to say for the sake of saying that I contend that the perspective of a non-tribal archaeologist will always be an outsiders perspective even if the content is intended to present the tribal communities perspective. We have been encouraging and empowering tribal members to present their perspectives and the perspectives of their tribal elders in their own words rather than us non-tribal archaeologists transcribing their perspectives for them.

# %%
df_sem_quotes.to_excel('/home/ekansa/oc-data/fair-care-semantic-quotes.xlsx')
