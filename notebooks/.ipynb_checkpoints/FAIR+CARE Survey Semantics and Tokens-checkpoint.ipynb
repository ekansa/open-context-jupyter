# %% [markdown]
# # Some Semantic Grouping Analysis of the FAIR-CARE Survey Text Responses

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

import os

import pandas as pd

from slugify import slugify

# Get the root_path for this jupyter notebook repo.
repo_path = os.path.dirname(os.path.abspath(os.getcwd()))
# Use this path to save the wordcloud outputs
wordcloud_1_path = os.path.join(
    repo_path, 'files', 'IMLS-FAIR-CARE-Survey', 'wordcloud-figs-1',
)

processed_survey_path = '/home/ekansa/oc-data/fair-care-survey-processed.csv' # Keep this OUT of version control, has sensitive info
token_freq_path = '/home/ekansa/oc-data/fair-care-token-freq.csv'
ngram_freq_path = '/home/ekansa/oc-data/fair-care-ngram-freq.csv'
semantic_clusters_path = '/home/ekansa/oc-data/fair-care-semantic-clusters.csv'


df = pd.read_csv(processed_survey_path, low_memory=False)
df_token = pd.read_csv(token_freq_path, low_memory=False)
df_ngram = pd.read_csv(ngram_freq_path, low_memory=False)
df_semantic = pd.read_csv(semantic_clusters_path, low_memory=False)

print(f'FAIR+CARE survey has {len(df.index)} rows')
print(f'FAIR+CARE survey token extract has {len(df_token.index)} rows')
print(f'FAIR+CARE survey ngram extract has {len(df_ngram.index)} rows')
print(f'FAIR+CARE survey semantic groupings has {len(df_semantic.index)} rows')
# Out:
# FAIR+CARE survey has 787 rows
# FAIR+CARE survey token extract has 62676 rows
# FAIR+CARE survey ngram extract has 396811 rows
# FAIR+CARE survey semantic groupings has 7242 rows

# %%
gen_group_cols = ['orig_column_index', 'column', 'semantic_group_st',]
use_index = df_semantic['orig_column_index'] >= 38
df_semantic_gp1 = df_semantic[use_index ][gen_group_cols].groupby(gen_group_cols, as_index=False).first()
df_semantic_gp1.sort_values(by=['orig_column_index', 'semantic_group_st',], ascending=[True, True], inplace=True)


# Repeatly used ngrams
print(f'There are {len(df_semantic_gp1.index)} unique semantic groups across all text fields')

df_semantic_gp1.head(100)
# Out:
# There are 205 unique semantic groups across all text fields
#     orig_column_index                                       column  \
# 0                  38      Data Role: How You Work with Data, Text
# 1                  38      Data Role: How You Work with Data, Text
# 2                  38      Data Role: How You Work with Data, Text
# 3                  38      Data Role: How You Work with Data, Text
# 4                  48                        Data Org: Other, Text
# ..                ...                                          ...
# 95                 81      Shared Terms: Shared Terms, Other, Text
# 96                 81      Shared Terms: Shared Terms, Other, Text
# 97                 81      Shared Terms: Shared Terms, Other, Text
# 98                 83  Media Used: Proprietary or Instrument, Text
# 99                 83  Media Used: Proprietary or Instrument, Text
#
#     semantic_group_st
# 0                   0
# 1                   1
# 2                   2
# 3                   3
# 4                   0
# ..                ...
# 95                  6
# 96                  7
# 97                  8
# 98                  0
# 99                  1
#
# [100 rows x 3 columns]

# %%
# Now Make WordClouds for each column, and each cluster
def create_wordcloud(text_dict, title=None, save_dir=wordcloud_1_path):
    wc = WordCloud(background_color="white", max_words=1000)
    wc.generate_from_frequencies(text_dict)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    if title:
        plt.title(title)
    slug_file = slugify(title)
    filename = f'{slug_file}.png'
    f_path = os.path.join(save_dir, filename)
    plt.savefig(f_path, bbox_inches='tight')
    print(f'Saved figure: {filename}')

token_join_cols = ['Response ID', 'token', 'token_count',]
semantic_join_cols = [
    'Response ID', 
    'orig_column_index', 
    'Question Number', 
    'Section', 
    'Sub-Section', 
    'column', 
    'response', 
    'semantic_group_st', 
    'bert_name_plain', 
    'bert_top_words_plain',
]
df_wc = pd.merge(df_token[token_join_cols], df_semantic[semantic_join_cols], how='left', on='Response ID')

# %%
use_index = df_wc['orig_column_index'] >= 38
df_wc_grp = df_wc[use_index].groupby(
    ['orig_column_index', 'semantic_group_st', 'token',], 
    as_index=False
).agg(
    {
        'column': 'first',
        'Question Number': 'first',
        'Section': 'first',
        'Sub-Section': 'first',
        'token_count': 'sum',
    }
)

for col in df_wc_grp['column'].unique().tolist():
    col_index = df_wc_grp['column'] == col
    sm_groups = df_wc_grp[col_index]['semantic_group_st'].unique().tolist()
    for sm_group in sm_groups:
        col_sm_index = col_index & ( df_wc_grp['semantic_group_st'] == sm_group)
        question = df_wc_grp[col_sm_index]['Question Number'].iloc[0]
        question = int(question)
        section = df_wc_grp[col_sm_index]['Section'].iloc[0]
        sub_section = df_wc_grp[col_sm_index]['Sub-Section'].iloc[0]
        title = f'{section} -- {sub_section} ({question}) {col} [Group {sm_group}]'
        text_dict = {}
        for _, row in df_wc_grp[col_sm_index].iterrows():
            if row['token'] == 'data':
                # not very interesting
                continue
            text_dict[row['token']] = row['token_count']
        create_wordcloud(text_dict, title)
# Out:
# Saved figure: demographics-data-role-1-0-data-role-how-you-work-with-data-text-group-0.png
# Saved figure: demographics-data-role-1-0-data-role-how-you-work-with-data-text-group-1.png
# Saved figure: demographics-data-role-1-0-data-role-how-you-work-with-data-text-group-2.png
# Saved figure: demographics-data-role-1-0-data-role-how-you-work-with-data-text-group-3.png
# Saved figure: fair-findable-2-0-data-org-other-text-group-0.png
# Saved figure: fair-findable-2-0-data-org-other-text-group-1.png
# Saved figure: fair-findable-2-0-data-org-other-text-group-2.png
# Saved figure: fair-findable-2-0-data-org-other-text-group-3.png
# Saved figure: fair-findable-2-0-data-org-other-text-group-4.png
# Saved figure: fair-findable-2-0-data-org-other-text-group-5.png
# Saved figure: fair-findable-2-0-data-org-other-text-group-6.png
# Saved figure: fair-findable-2-0-data-org-other-text-group-7.png
# Saved figure: fair-findable-3-0-data-store-data-storage-other-text-group-0.png
# Saved figure: fair-findable-3-0-data-store-data-storage-other-text-group-1.png
# Saved figure: fair-findable-3-0-data-store-data-storage-other-text-group-2.png
# Saved figure: fair-findable-3-0-data-store-data-storage-other-text-group-3.png
# Saved figure: fair-findable-3-0-data-store-data-storage-other-text-group-4.png
# Saved figure: fair-findable-3-0-data-store-data-storage-other-text-group-5.png
# Saved figure: fair-findable-3-0-data-store-data-storage-other-text-group-6.png
# Saved figure: fair-findable-3-0-data-store-data-storage-other-text-group-7.png
# Saved figure: fair-findable-4-0-findable-yes-text-group-0.png
# Saved figure: fair-findable-4-0-findable-yes-text-group-1.png
# Saved figure: fair-findable-4-0-findable-yes-text-group-2.png
# Saved figure: fair-findable-4-0-findable-yes-text-group-3.png
# Saved figure: fair-findable-4-0-findable-yes-text-group-4.png
# Saved figure: fair-findable-4-0-findable-yes-text-group-5.png
# Saved figure: fair-findable-4-0-findable-yes-text-group-6.png
# Saved figure: fair-findable-4-0-findable-yes-text-group-7.png
# Saved figure: fair-findable-4-0-findable-no-explain-text-group-0.png
# Saved figure: fair-findable-4-0-findable-no-explain-text-group-1.png
# Saved figure: fair-findable-4-0-findable-no-explain-text-group-2.png
# Saved figure: fair-findable-4-0-findable-sometimes-explain-text-group-0.png
# Saved figure: fair-findable-5-0-identifiers-other-text-group-0.png
# Saved figure: fair-findable-5-0-identifiers-other-text-group-1.png
# Saved figure: fair-findable-5-0-identifiers-other-text-group-2.png
# Saved figure: fair-findable-5-0-identifiers-other-text-group-3.png
# Saved figure: fair-findable-5-0-identifiers-other-text-group-4.png
# Saved figure: fair-findable-5-0-identifiers-other-text-group-5.png
# Saved figure: fair-findable-5-0-identifiers-other-text-group-6.png
# Saved figure: fair-findable-5-0-identifiers-other-text-group-7.png
# Saved figure: fair-findable-5-0-identifiers-other-text-group-8.png
# Saved figure: fair-findable-5-0-identifiers-other-text-group-9.png
# Saved figure: fair-findable-7-0-metadata-search-metadata-search-method-text-group-0.png
# Saved figure: fair-findable-7-0-metadata-search-metadata-search-method-text-group-1.png
# Saved figure: fair-findable-7-0-metadata-search-metadata-search-method-text-group-2.png
# Saved figure: fair-findable-7-0-metadata-search-metadata-search-method-text-group-3.png
# Saved figure: fair-findable-7-0-metadata-search-metadata-search-method-text-group-4.png
# Saved figure: fair-findable-7-0-metadata-search-metadata-search-method-text-group-5.png
# Saved figure: fair-findable-7-0-metadata-search-metadata-search-method-text-group-6.png
# Saved figure: fair-findable-7-0-metadata-search-metadata-search-method-text-group-7.png
# Saved figure: fair-findable-8-0-supplemental-data-other-text-group-0.png
# Saved figure: fair-findable-8-0-supplemental-data-other-text-group-1.png
# Saved figure: fair-findable-8-0-supplemental-data-other-text-group-2.png
# Saved figure: fair-findable-8-0-supplemental-data-other-text-group-3.png
# Saved figure: fair-findable-8-0-supplemental-data-other-text-group-4.png
# Saved figure: fair-findable-8-0-supplemental-data-other-text-group-5.png
# Saved figure: fair-findable-8-0-supplemental-data-other-text-group-6.png
# Saved figure: fair-findable-9-0-cost-paid-other-text-group-0.png
# Saved figure: fair-findable-9-0-cost-paid-other-text-group-1.png
# Saved figure: fair-findable-9-0-cost-paid-other-text-group-2.png
# Saved figure: fair-findable-9-0-cost-paid-other-text-group-3.png
# Saved figure: fair-findable-9-0-cost-paid-other-text-group-4.png
# Saved figure: fair-findable-9-0-cost-paid-other-text-group-5.png
# Saved figure: fair-findable-9-0-cost-paid-other-text-group-6.png
# Saved figure: fair-findable-9-0-cost-paid-other-text-group-7.png
# Saved figure: fair-findable-9-0-cost-paid-other-text-group-8.png
# Saved figure: fair-accessible-10-0-accessible-additional-info-text-group-0.png
# Saved figure: fair-accessible-10-0-accessible-additional-info-text-group-1.png
# Saved figure: fair-accessible-10-0-accessible-additional-info-text-group-2.png
# Saved figure: fair-accessible-10-0-accessible-additional-info-text-group-3.png
# Saved figure: fair-accessible-10-0-accessible-additional-info-text-group-4.png
# Saved figure: fair-accessible-10-0-accessible-additional-info-text-group-5.png
# Saved figure: fair-accessible-11-0-why-acquire-other-text-group-0.png
# Saved figure: fair-accessible-11-0-why-acquire-other-text-group-1.png
# Saved figure: fair-accessible-11-0-why-acquire-other-text-group-2.png
# Saved figure: fair-accessible-11-0-why-acquire-other-text-group-3.png
# Saved figure: fair-accessible-11-0-why-acquire-other-text-group-4.png
# Saved figure: fair-accessible-11-0-why-acquire-other-text-group-5.png
# Saved figure: fair-accessible-12-0-how-acquire-other-text-group-0.png
# Saved figure: fair-accessible-12-0-how-acquire-other-text-group-1.png
# Saved figure: fair-interoperable-14-0-understanding-problems-understanding-data-group-0.png
# Saved figure: fair-interoperable-14-0-understanding-problems-understanding-data-group-1.png
# Saved figure: fair-interoperable-14-0-understanding-problems-understanding-data-text-group-0.png
# Saved figure: fair-interoperable-14-0-understanding-problems-understanding-data-text-group-1.png
# Saved figure: fair-interoperable-14-0-understanding-problems-understanding-data-text-group-2.png
# Saved figure: fair-interoperable-15-0-shared-terms-shared-terms-co-created-text-group-0.png
# Saved figure: fair-interoperable-15-0-shared-terms-shared-terms-co-created-text-group-1.png
# Saved figure: fair-interoperable-15-0-shared-terms-shared-terms-co-created-text-group-2.png
# Saved figure: fair-interoperable-15-0-shared-terms-shared-terms-co-created-text-group-3.png
# Saved figure: fair-interoperable-15-0-shared-terms-shared-terms-other-text-group-0.png
# Saved figure: fair-interoperable-15-0-shared-terms-shared-terms-other-text-group-1.png
# Saved figure: fair-interoperable-15-0-shared-terms-shared-terms-other-text-group-2.png
# Saved figure: fair-interoperable-15-0-shared-terms-shared-terms-other-text-group-3.png
# Saved figure: fair-interoperable-15-0-shared-terms-shared-terms-other-text-group-4.png
# Saved figure: fair-interoperable-15-0-shared-terms-shared-terms-other-text-group-5.png
# Saved figure: fair-interoperable-15-0-shared-terms-shared-terms-other-text-group-6.png
# Saved figure: fair-interoperable-15-0-shared-terms-shared-terms-other-text-group-7.png
# Saved figure: fair-interoperable-15-0-shared-terms-shared-terms-other-text-group-8.png
# Saved figure: fair-reusable-16-0-media-used-proprietary-or-instrument-text-group-0.png
# Saved figure: fair-reusable-16-0-media-used-proprietary-or-instrument-text-group-1.png
# Saved figure: fair-reusable-16-0-media-used-proprietary-or-instrument-text-group-2.png
# Saved figure: fair-reusable-16-0-media-used-other-text-group-0.png
# Saved figure: fair-reusable-16-0-media-used-other-text-group-1.png
# Saved figure: fair-reusable-16-0-media-used-other-text-group-2.png
# Saved figure: fair-reusable-16-0-media-used-other-text-group-3.png
# Saved figure: fair-reusable-16-0-media-used-other-text-group-4.png
# Saved figure: fair-reusable-16-0-media-used-other-text-group-5.png
# Saved figure: fair-reusable-16-0-media-used-other-text-group-6.png
# Saved figure: fair-reusable-16-0-media-used-other-text-group-7.png
# Saved figure: fair-reusable-17-0-reuse-expectations-other-conditions-text-group-0.png
# Saved figure: fair-reusable-17-0-reuse-expectations-other-conditions-text-group-1.png
# Saved figure: fair-reusable-18-0-security-data-security-measures-group-0.png
# Saved figure: fair-reusable-18-0-security-data-security-measures-group-1.png
# Saved figure: fair-reusable-18-0-security-compliance-with-other-industry-regulations-text-group-0.png
# Saved figure: fair-reusable-18-0-security-compliance-with-other-industry-regulations-text-group-1.png
# Saved figure: fair-reusable-18-0-security-compliance-with-other-industry-regulations-text-group-2.png
# Saved figure: fair-reusable-18-0-security-compliance-with-other-industry-regulations-text-group-3.png
# Saved figure: fair-reusable-18-0-security-compliance-with-other-industry-regulations-text-group-4.png
# Saved figure: fair-reusable-18-0-security-compliance-with-other-industry-regulations-text-group-5.png
# Saved figure: fair-reusable-18-0-security-compliance-with-other-industry-regulations-text-group-6.png
# Saved figure: fair-reusable-18-0-security-compliance-with-other-industry-regulations-text-group-7.png
# Saved figure: fair-reusable-18-0-security-other-text-group-0.png
# Saved figure: fair-reusable-18-0-security-other-text-group-1.png
# Saved figure: fair-reusable-18-0-security-other-text-group-2.png
# Saved figure: fair-reusable-18-0-security-other-text-group-3.png
# Saved figure: fair-reusable-18-0-security-other-text-group-4.png
# Saved figure: fair-reusable-18-0-security-other-text-group-5.png
# Saved figure: fair-reusable-18-0-security-other-text-group-6.png
# Saved figure: fair-reusable-19-0-secure-info-confidential-data-types-group-0.png
# Saved figure: fair-reusable-19-0-secure-info-confidential-data-types-group-1.png
# Saved figure: care-general-21-0-care-define-indigenous-data-text-group-0.png
# Saved figure: care-general-21-0-care-define-indigenous-data-text-group-1.png
# Saved figure: care-collective-benefit-22-0-engage-policies-policies-for-indigenous-descendant-engagement-examples-text-group-0.png
# Saved figure: care-collective-benefit-22-0-engage-policies-policies-for-indigenous-descendant-engagement-examples-text-group-1.png
# Saved figure: care-collective-benefit-25-0-disclosure-process-indigenous-and-or-descendant-disclosure-examples-text-group-0.png
# Saved figure: care-collective-benefit-25-0-disclosure-process-indigenous-and-or-descendant-disclosure-examples-text-group-1.png
# Saved figure: care-collective-benefit-25-0-disclosure-process-indigenous-and-or-descendant-disclosure-examples-text-group-2.png
# Saved figure: care-collective-benefit-27-0-reuse-process-examples-text-group-0.png
# Saved figure: care-collective-benefit-27-0-reuse-process-examples-text-group-1.png
# Saved figure: care-authority-to-control-29-0-control-policies-polices-for-indigenous-use-refusal-reclaim-data-yes-text-group-0.png
# Saved figure: care-authority-to-control-29-0-control-policies-polices-for-indigenous-use-refusal-reclaim-data-yes-text-group-1.png
# Saved figure: care-authority-to-control-29-0-control-policies-polices-for-indigenous-use-refusal-reclaim-data-yes-text-group-2.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 30
#      28         continue
#      29     text_dict[row['token']] = row['token_count']
# ---> 30 create_wordcloud(text_dict, title)
#
# Cell In[3], line 12, in create_wordcloud(text_dict, title, save_dir)
#      10 filename = f'{slug_file}.png'
#      11 f_path = os.path.join(save_dir, filename)
# ---> 12 plt.savefig(f_path, bbox_inches='tight')
#      13 print(f'Saved figure: {filename}')
#
# File ~/.local/share/virtualenvs/open-context-jupyter-79gHXrqC/lib/python3.10/site-packages/matplotlib/pyplot.py:1228, in savefig(*args, **kwargs)
#    1225 fig = gcf()
#    1226 # savefig default implementation has no return, so mypy is unhappy
#    1227 # presumably this is here because subclasses can return?
# -> 1228 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1229 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1230 return res
#
# File ~/.local/share/virtualenvs/open-context-jupyter-79gHXrqC/lib/python3.10/site-packages/matplotlib/figure.py:3395, in Figure.savefig(self, fname, transparent, **kwargs)
#    3393     for ax in self.axes:
#    3394         _recursively_make_axes_transparent(stack, ax)
# -> 3395 self.canvas.print_figure(fname, **kwargs)
#
# File ~/.local/share/virtualenvs/open-context-jupyter-79gHXrqC/lib/python3.10/site-packages/matplotlib/backend_bases.py:2204, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2200 try:
#    2201     # _get_renderer may change the figure dpi (as vector formats
#    2202     # force the figure dpi to 72), so we need to set it again here.
#    2203     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2204         result = print_method(
#    2205             filename,
#    2206             facecolor=facecolor,
#    2207             edgecolor=edgecolor,
#    2208             orientation=orientation,
#    2209             bbox_inches_restore=_bbox_inches_restore,
#    2210             **kwargs)
#    2211 finally:
#    2212     if bbox_inches and restore_bbox:
#
# File ~/.local/share/virtualenvs/open-context-jupyter-79gHXrqC/lib/python3.10/site-packages/matplotlib/backend_bases.py:2054, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2050     optional_kws = {  # Passed by print_figure for other renderers.
#    2051         "dpi", "facecolor", "edgecolor", "orientation",
#    2052         "bbox_inches_restore"}
#    2053     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2054     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2055         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2056 else:  # Let third-parties do as they see fit.
#    2057     print_method = meth
#
# File ~/.local/share/virtualenvs/open-context-jupyter-79gHXrqC/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:496, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     449 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     450     """
#     451     Write the figure to a PNG file.
#     452
#    (...)
#     494         *metadata*, including the default 'Software' key.
#     495     """
# --> 496     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/.local/share/virtualenvs/open-context-jupyter-79gHXrqC/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:444, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     439 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     440     """
#     441     Draw the canvas, then save it using `.image.imsave` (to which
#     442     *pil_kwargs* and *metadata* are forwarded).
#     443     """
# --> 444     FigureCanvasAgg.draw(self)
#     445     mpl.image.imsave(
#     446         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     447         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/.local/share/virtualenvs/open-context-jupyter-79gHXrqC/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:387, in FigureCanvasAgg.draw(self)
#     384 # Acquire a lock on the shared font cache.
#     385 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     386       else nullcontext()):
# --> 387     self.figure.draw(self.renderer)
#     388     # A GUI class may be need to update a window using this draw, so
#     389     # don't forget to call the superclass.
#     390     super().draw()
#
# File ~/.local/share/virtualenvs/open-context-jupyter-79gHXrqC/lib/python3.10/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~/.local/share/virtualenvs/open-context-jupyter-79gHXrqC/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/.local/share/virtualenvs/open-context-jupyter-79gHXrqC/lib/python3.10/site-packages/matplotlib/figure.py:3162, in Figure.draw(self, renderer)
#    3159             # ValueError can occur when resizing a window.
#    3161     self.patch.draw(renderer)
# -> 3162     mimage._draw_list_compositing_images(
#    3163         renderer, self, artists, self.suppressComposite)
#    3165     renderer.close_group('figure')
#    3166 finally:
#
# File ~/.local/share/virtualenvs/open-context-jupyter-79gHXrqC/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/.local/share/virtualenvs/open-context-jupyter-79gHXrqC/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/.local/share/virtualenvs/open-context-jupyter-79gHXrqC/lib/python3.10/site-packages/matplotlib/axes/_base.py:3137, in _AxesBase.draw(self, renderer)
#    3134 if artists_rasterized:
#    3135     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3137 mimage._draw_list_compositing_images(
#    3138     renderer, self, artists, self.figure.suppressComposite)
#    3140 renderer.close_group('axes')
#    3141 self.stale = False
#
# File ~/.local/share/virtualenvs/open-context-jupyter-79gHXrqC/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/.local/share/virtualenvs/open-context-jupyter-79gHXrqC/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/.local/share/virtualenvs/open-context-jupyter-79gHXrqC/lib/python3.10/site-packages/matplotlib/image.py:653, in _ImageBase.draw(self, renderer)
#     651         renderer.draw_image(gc, l, b, im, trans)
#     652 else:
# --> 653     im, l, b, trans = self.make_image(
#     654         renderer, renderer.get_image_magnification())
#     655     if im is not None:
#     656         renderer.draw_image(gc, l, b, im)
#
# File ~/.local/share/virtualenvs/open-context-jupyter-79gHXrqC/lib/python3.10/site-packages/matplotlib/image.py:952, in AxesImage.make_image(self, renderer, magnification, unsampled)
#     949 transformed_bbox = TransformedBbox(bbox, trans)
#     950 clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     951         else self.figure.bbox)
# --> 952 return self._make_image(self._A, bbox, transformed_bbox, clip,
#     953                         magnification, unsampled=unsampled)
#
# File ~/.local/share/virtualenvs/open-context-jupyter-79gHXrqC/lib/python3.10/site-packages/matplotlib/image.py:568, in _ImageBase._make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     564     else:
#     565         output_alpha = _resample(  # resample alpha channel
#     566             self, A[..., 3], out_shape, t, alpha=alpha)
#     567     output = _resample(  # resample rgb channels
# --> 568         self, _rgb_to_rgba(A[..., :3]), out_shape, t, alpha=alpha)
#     569     output[..., 3] = output_alpha  # recombine rgb and alpha
#     571 # output is now either a 2D array of normed (int or float) data
#     572 # or an RGBA array of re-sampled input
#
# KeyboardInterrupt:

# %%
len(df_semantic[(df_semantic['Section'] == '0')].index)
