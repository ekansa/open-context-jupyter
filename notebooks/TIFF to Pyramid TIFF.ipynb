# %% [markdown]
# ## Convert TIFF images to Pyramidal Tiled TIFF images
#
# This notebook processes through directories of TIFF image files to convert them to pyramidal tiled TIFF image files.
#
# You must first install "libvips" (https://www.libvips.org/) with these instructions:
# https://www.libvips.org/install.html

# %%
import os

# Get the root_path for this jupyter notebook repo.
repo_path = os.path.dirname(os.path.abspath(os.getcwd()))

# path where image files are stored for this workbook.
# The 'tiffs' directory is under .gitignore so that we don't acciddentally
# commit image files to this repo. But you may need to manually create the
# 'tiffs' directory for this to run.
path_tiffs = os.path.join(
    repo_path, 'files', 'tiffs'
)

# NOTE: you can change path_tiffs
# to a different location on your file system

file_paths = []
for dirpath, _, filenames in os.walk(path_tiffs):
    for filename in filenames:
        extension = os.path.splitext(filename)[1]
        if not 'tif' in extension.lower():
            # we're skipping this file because it lacks the required .TIFF/.TIF extension.
            continue
        if filename.endswith(':Zone.Identifier'):
            # A convenience hack to skip Windows subsystem for linux debris
            continue
        if filename.startswith('.'):
            # A convenience hack to skip other random file system debris
            continue
        if filename.endswith('_pyr.tif'):
            # We already processed this image
            continue
        file_path = os.path.join(dirpath, filename)
        file_paths.append(file_path)
print(f'We have {len(file_paths)} files to process')
# Out:
# We have 6 files to process

# %%
for file_path in file_paths:
    new_path = os.path.splitext(file_path)[0] + '_pyr.tif'
    print(f'working on {file_path} -> {new_path}')
    # Make a string for the command to convert the TIFF image to a pyramidal tiled TIFF
    cmd = f'vips im_vips2tiff {file_path} {new_path}:deflate,tile:256x256,pyramid'
    # Now execute the command
    code = os.system(cmd)
    # Show some output of progress
    print(f'{new_path} code: {code}')
# Out:
# working on /home/ekansa/github/open-context-jupyter/files/tiffs/s0108V1962/s0108V1962_b.tif -> /home/ekansa/github/open-context-jupyter/files/tiffs/s0108V1962/s0108V1962_b_pyr.tif
# (vips:25371): VIPS-WARNING **: 09:19:42.430: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.430: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.430: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.430: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.430: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.430: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.430: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.430: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.430: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.430: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.432: rounding up IPTC data length
#
# (vips:25371): VIPS-WARNING **: 09:19:42.432: rounding up IPTC data length
#
# (vips:25371): VIPS-WARNING **: 09:19:42.432: rounding up IPTC data length
#
# (vips:25371): VIPS-WARNING **: 09:19:42.432: rounding up IPTC data length
#
# (vips:25371): VIPS-WARNING **: 09:19:42.432: rounding up IPTC data length
#
# (vips:25371): VIPS-WARNING **: 09:19:42.432: rounding up IPTC data length
#
# (vips:25371): VIPS-WARNING **: 09:19:42.433: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.433: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.434: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.434: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.434: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.434: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.434: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.434: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.434: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.434: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.434: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:42.434: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25371): VIPS-WARNING **: 09:19:56.490: rounding up IPTC data length
#
# (vips:25371): VIPS-WARNING **: 09:19:58.751: rounding up IPTC data length
#
# (vips:25371): VIPS-WARNING **: 09:19:59.320: rounding up IPTC data length
#
# (vips:25371): VIPS-WARNING **: 09:19:59.455: rounding up IPTC data length
#
# (vips:25371): VIPS-WARNING **: 09:19:59.498: rounding up IPTC data length
# /home/ekansa/github/open-context-jupyter/files/tiffs/s0108V1962/s0108V1962_b_pyr.tif code: 0
# working on /home/ekansa/github/open-context-jupyter/files/tiffs/s0039V1962/s0039V1962_b.tif -> /home/ekansa/github/open-context-jupyter/files/tiffs/s0039V1962/s0039V1962_b_pyr.tif
# (vips:25410): VIPS-WARNING **: 09:19:59.591: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.591: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.591: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.591: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.591: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.591: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.591: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.591: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.591: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.591: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.593: rounding up IPTC data length
#
# (vips:25410): VIPS-WARNING **: 09:19:59.593: rounding up IPTC data length
#
# (vips:25410): VIPS-WARNING **: 09:19:59.593: rounding up IPTC data length
#
# (vips:25410): VIPS-WARNING **: 09:19:59.593: rounding up IPTC data length
#
# (vips:25410): VIPS-WARNING **: 09:19:59.593: rounding up IPTC data length
#
# (vips:25410): VIPS-WARNING **: 09:19:59.593: rounding up IPTC data length
#
# (vips:25410): VIPS-WARNING **: 09:19:59.594: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.594: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.594: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.594: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.594: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.594: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.594: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.594: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.595: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.595: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.595: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25410): VIPS-WARNING **: 09:19:59.595: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25410): VIPS-WARNING **: 09:20:14.621: rounding up IPTC data length
#
# (vips:25410): VIPS-WARNING **: 09:20:16.876: rounding up IPTC data length
#
# (vips:25410): VIPS-WARNING **: 09:20:17.428: rounding up IPTC data length
#
# (vips:25410): VIPS-WARNING **: 09:20:17.570: rounding up IPTC data length
#
# (vips:25410): VIPS-WARNING **: 09:20:17.617: rounding up IPTC data length
# /home/ekansa/github/open-context-jupyter/files/tiffs/s0039V1962/s0039V1962_b_pyr.tif code: 0
# working on /home/ekansa/github/open-context-jupyter/files/tiffs/s0240V1962/s0240V1962_b.tif -> /home/ekansa/github/open-context-jupyter/files/tiffs/s0240V1962/s0240V1962_b_pyr.tif
# (vips:25449): VIPS-WARNING **: 09:20:17.688: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.688: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.688: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.688: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.688: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.688: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.688: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.688: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.688: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.688: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.690: rounding up IPTC data length
#
# (vips:25449): VIPS-WARNING **: 09:20:17.690: rounding up IPTC data length
#
# (vips:25449): VIPS-WARNING **: 09:20:17.690: rounding up IPTC data length
#
# (vips:25449): VIPS-WARNING **: 09:20:17.690: rounding up IPTC data length
#
# (vips:25449): VIPS-WARNING **: 09:20:17.690: rounding up IPTC data length
#
# (vips:25449): VIPS-WARNING **: 09:20:17.690: rounding up IPTC data length
#
# (vips:25449): VIPS-WARNING **: 09:20:17.691: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.691: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.691: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.691: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.691: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.691: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.692: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.692: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.692: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.692: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.692: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:17.692: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25449): VIPS-WARNING **: 09:20:32.681: rounding up IPTC data length
#
# (vips:25449): VIPS-WARNING **: 09:20:34.973: rounding up IPTC data length
#
# (vips:25449): VIPS-WARNING **: 09:20:35.519: rounding up IPTC data length
#
# (vips:25449): VIPS-WARNING **: 09:20:35.656: rounding up IPTC data length
#
# (vips:25449): VIPS-WARNING **: 09:20:35.701: rounding up IPTC data length
# /home/ekansa/github/open-context-jupyter/files/tiffs/s0240V1962/s0240V1962_b_pyr.tif code: 0
# working on /home/ekansa/github/open-context-jupyter/files/tiffs/s0107V1962/s0107V1962_gb.tif -> /home/ekansa/github/open-context-jupyter/files/tiffs/s0107V1962/s0107V1962_gb_pyr.tif
# (vips:25487): VIPS-WARNING **: 09:20:35.773: Incompatible type for "RichTIFFIPTC"; tag ignored
#
# (vips:25487): VIPS-WARNING **: 09:20:35.773: Incompatible type for "RichTIFFIPTC"; tag ignored
#
# (vips:25487): VIPS-WARNING **: 09:20:35.773: Incompatible type for "RichTIFFIPTC"; tag ignored
#
# (vips:25487): VIPS-WARNING **: 09:20:35.773: Incompatible type for "RichTIFFIPTC"; tag ignored
#
# (vips:25487): VIPS-WARNING **: 09:20:35.773: Incompatible type for "RichTIFFIPTC"; tag ignored
#
# (vips:25487): VIPS-WARNING **: 09:20:35.776: Incompatible type for "RichTIFFIPTC"; tag ignored
#
# (vips:25487): VIPS-WARNING **: 09:20:35.777: Incompatible type for "RichTIFFIPTC"; tag ignored
#
# (vips:25487): VIPS-WARNING **: 09:20:35.777: Incompatible type for "RichTIFFIPTC"; tag ignored
#
# (vips:25487): VIPS-WARNING **: 09:20:35.777: Incompatible type for "RichTIFFIPTC"; tag ignored
#
# (vips:25487): VIPS-WARNING **: 09:20:35.777: Incompatible type for "RichTIFFIPTC"; tag ignored
#
# (vips:25487): VIPS-WARNING **: 09:20:35.777: Incompatible type for "RichTIFFIPTC"; tag ignored
# /home/ekansa/github/open-context-jupyter/files/tiffs/s0107V1962/s0107V1962_gb_pyr.tif code: 0
# working on /home/ekansa/github/open-context-jupyter/files/tiffs/s0243V1962/s0243V1962_b.tif -> /home/ekansa/github/open-context-jupyter/files/tiffs/s0243V1962/s0243V1962_b_pyr.tif
# (vips:25526): VIPS-WARNING **: 09:20:51.617: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.617: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.618: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.618: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.618: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.618: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.618: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.618: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.618: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.618: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.619: rounding up IPTC data length
#
# (vips:25526): VIPS-WARNING **: 09:20:51.619: rounding up IPTC data length
#
# (vips:25526): VIPS-WARNING **: 09:20:51.620: rounding up IPTC data length
#
# (vips:25526): VIPS-WARNING **: 09:20:51.620: rounding up IPTC data length
#
# (vips:25526): VIPS-WARNING **: 09:20:51.622: rounding up IPTC data length
#
# (vips:25526): VIPS-WARNING **: 09:20:51.622: rounding up IPTC data length
#
# (vips:25526): VIPS-WARNING **: 09:20:51.622: rounding up IPTC data length
#
# (vips:25526): VIPS-WARNING **: 09:20:51.623: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.623: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.624: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.624: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.639: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.639: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.639: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.639: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.639: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.639: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.639: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25526): VIPS-WARNING **: 09:20:51.639: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25526): VIPS-WARNING **: 09:21:13.403: rounding up IPTC data length
#
# (vips:25526): VIPS-WARNING **: 09:21:17.633: rounding up IPTC data length
#
# (vips:25526): VIPS-WARNING **: 09:21:18.857: rounding up IPTC data length
#
# (vips:25526): VIPS-WARNING **: 09:21:19.199: rounding up IPTC data length
#
# (vips:25526): VIPS-WARNING **: 09:21:19.296: rounding up IPTC data length
#
# (vips:25526): VIPS-WARNING **: 09:21:19.339: rounding up IPTC data length
# /home/ekansa/github/open-context-jupyter/files/tiffs/s0243V1962/s0243V1962_b_pyr.tif code: 0
# working on /home/ekansa/github/open-context-jupyter/files/tiffs/s0196V1962/s0196V1962_b.tif -> /home/ekansa/github/open-context-jupyter/files/tiffs/s0196V1962/s0196V1962_b_pyr.tif
# (vips:25565): VIPS-WARNING **: 09:21:19.443: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.443: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.444: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.444: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.444: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.444: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.444: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.444: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.444: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.444: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.445: rounding up IPTC data length
#
# (vips:25565): VIPS-WARNING **: 09:21:19.445: rounding up IPTC data length
#
# (vips:25565): VIPS-WARNING **: 09:21:19.445: rounding up IPTC data length
#
# (vips:25565): VIPS-WARNING **: 09:21:19.445: rounding up IPTC data length
#
# (vips:25565): VIPS-WARNING **: 09:21:19.446: rounding up IPTC data length
#
# (vips:25565): VIPS-WARNING **: 09:21:19.446: rounding up IPTC data length
#
# (vips:25565): VIPS-WARNING **: 09:21:19.446: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.446: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.447: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.447: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.447: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.447: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.447: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.447: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.447: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.447: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.447: Unknown field with tag 34152 (0x8568) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:19.447: Unknown field with tag 50460 (0xc51c) encountered
#
# (vips:25565): VIPS-WARNING **: 09:21:34.035: rounding up IPTC data length
#
# (vips:25565): VIPS-WARNING **: 09:21:36.124: rounding up IPTC data length
#
# (vips:25565): VIPS-WARNING **: 09:21:36.684: rounding up IPTC data length
#
# (vips:25565): VIPS-WARNING **: 09:21:36.811: rounding up IPTC data length
#
# (vips:25565): VIPS-WARNING **: 09:21:36.854: rounding up IPTC data length
# /home/ekansa/github/open-context-jupyter/files/tiffs/s0196V1962/s0196V1962_b_pyr.tif code: 0
